# %%
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
cons_no = 2323237963

# %%
cons_info = pd.read_csv("../data/测试组_比特币挖矿_档案明细（20211220）.csv", index_col=0, quotechar='"', encoding="gbk")

# %%
cons_info_one = cons_info[cons_info.index == cons_no]
cons_info_one
# Out:
#            ELEC_TYPE_NAME VOLT_NAME      PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 2323237963       城镇居民生活用电    交流380V  居民生活<1kV(合表)        1168.0   1168.0
#
#             SHIFT_NO         BUILD_DATE CANCEL_DATE  CHK_CYCLE LAST_CHK_DATE  \
# ID
# 2323237963       NaN  2016/12/8 8:24:00         NaN         12      2021/3/1
#
#            TMP_NAME  TMP_DATE
# ID
# 2323237963    非临时用电       NaN

# %%
elec_month = pd.read_csv("../data/测试组_比特币挖矿_月用电明细（20211217）.csv")
elec_month
# Out:
#                 id      ym  pq_f  pq_g  pq_p  pq_z
# 0        179438260  202001   244   111     1   356
# 1        179438260  202002   217   108    -1   324
# 2        179438260  202003   280    90     0   370
# 3        179438260  202004   338   118     1   457
# 4        179438260  202005   297   120    -1   416
# ...            ...     ...   ...   ...   ...   ...
# 338333  2880712108  202106   474   675     0  1149
# 338334  2880712108  202107   342   881     0  1223
# 338335  2880712108  202108   293   772     0  1065
# 338336  2880712108  202109   418   570    -1   987
# 338337  2880712108  202110   549   535     1  1085
#
# [338338 rows x 6 columns]

# %%
elec_month["ym"] = elec_month["ym"].astype(str)
elec_month
# Out:
#                 id      ym  pq_f  pq_g  pq_p  pq_z
# 0        179438260  202001   244   111     1   356
# 1        179438260  202002   217   108    -1   324
# 2        179438260  202003   280    90     0   370
# 3        179438260  202004   338   118     1   457
# 4        179438260  202005   297   120    -1   416
# ...            ...     ...   ...   ...   ...   ...
# 338333  2880712108  202106   474   675     0  1149
# 338334  2880712108  202107   342   881     0  1223
# 338335  2880712108  202108   293   772     0  1065
# 338336  2880712108  202109   418   570    -1   987
# 338337  2880712108  202110   549   535     1  1085
#
# [338338 rows x 6 columns]

# %%
elec_month_one = elec_month[elec_month["id"] == cons_no]
elec_month_one
# Out:
#                 id      ym  pq_f  pq_g  pq_p   pq_z
# 294866  2323237963  202001  2251  2177  2256   6684
# 294867  2323237963  202002  2275  2177  2304   6756
# 294868  2323237963  202003  3862  1968  3508   9338
# 294869  2323237963  202004  3370  2184  2956   8510
# 294870  2323237963  202005  2186  2098  2249   6533
# 294871  2323237963  202006  3583  2167  2756   8506
# 294872  2323237963  202007  2230  2078  2210   6518
# 294873  2323237963  202008  3891  2287  2476   8654
# 294874  2323237963  202009  4726  2422  2702   9850
# 294875  2323237963  202010  7291  4440  4981  16712
# 294876  2323237963  202011  3622  2011  2203   7836
# 294877  2323237963  202012  3134  2107  2252   7493
# 294878  2323237963  202101  2410  2119  2287   6816
# 294879  2323237963  202102  1956  1742  1846   5544
# 294880  2323237963  202103  2273  1958  2136   6367
# 294881  2323237963  202104  1944  1750  1857   5551
# 294882  2323237963  202105  2299  1807  1995   6101
# 294883  2323237963  202106  2542  1978  2229   6749
# 294884  2323237963  202107  2498  2119  2343   6960
# 294885  2323237963  202108  4339  2227  2612   9178
# 294886  2323237963  202109  5784  2587  3259  11630
# 294887  2323237963  202110  4970  2494  2945  10409

# %%
elec_month_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 294866 to 294887
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      22 non-null     int64
#  1   ym      22 non-null     object
#  2   pq_f    22 non-null     int64
#  3   pq_g    22 non-null     int64
#  4   pq_p    22 non-null     int64
#  5   pq_z    22 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.2+ KB

# %%
plt.figure(1)
plt.plot(elec_month_one["ym"], elec_month_one["pq_f"], color="r", label="pq_f")
plt.plot(elec_month_one["ym"], elec_month_one["pq_g"], color="g", label="pq_g")
plt.plot(elec_month_one["ym"], elec_month_one["pq_p"], color="b", label="pq_p")
plt.xlabel("ym")
plt.ylabel("elec_month")
plt.title("month_curve")
plt.xticks(rotation=60)
plt.legend()
plt.tight_layout()
plt.show()

# %%
elec_day = pd.read_csv("../data/测试组_比特币挖矿_日用电明细（20211217）.csv")
elec_day["rq"] = pd.to_datetime(elec_day["rq"])
elec_day_one = elec_day[elec_day["id"] == cons_no]
elec_day_one
# Out:
#                  id         rq    kwh  kwh_rap  kwh_pap_r1  kwh_pap_r2  \
# 1447237  2323237963 2020-01-22  218.4      NaN         0.0        72.0
# 1447238  2323237963 2020-01-23  216.0      NaN         0.0        72.0
# 1447239  2323237963 2020-01-24  223.2      NaN         0.0        74.4
# 1447240  2323237963 2020-01-25  223.2      NaN         0.0        76.8
# 1447241  2323237963 2020-01-26  216.0      NaN         0.0        72.0
# ...             ...        ...    ...      ...         ...         ...
# 1447340  2323237963 2021-10-05  333.6      NaN         0.0       144.0
# 1447341  2323237963 2021-10-06  331.2      NaN         0.0       144.0
# 1447342  2323237963 2021-10-07  314.4      NaN         0.0       127.2
# 1447343  2323237963 2021-10-08  357.6      NaN         0.0       163.2
# 1447344  2323237963 2021-10-09  456.0      NaN         0.0       211.2
#
#          kwh_pap_r3  kwh_pap_r4
# 1447237        74.4        72.0
# 1447238        74.4        69.6
# 1447239        79.2        69.6
# 1447240        72.0        74.4
# 1447241        72.0        72.0
# ...             ...         ...
# 1447340        96.0        93.6
# 1447341        96.0        91.2
# 1447342        98.4        88.8
# 1447343       103.2        93.6
# 1447344       153.6        88.8
#
# [108 rows x 8 columns]

# %%
plt.figure(2)
plt.plot(list(range(elec_day_one["kwh_pap_r2"].shape[0])), elec_day_one["kwh_pap_r2"], color="r", label="kwh_pap_r2")
plt.plot(list(range(elec_day_one["kwh_pap_r3"].shape[0])), elec_day_one["kwh_pap_r3"], color="g", label="kwh_pap_r3")
plt.plot(list(range(elec_day_one["kwh_pap_r3"].shape[0])), elec_day_one["kwh_pap_r4"], color="b", label="kwh_pap_r4")
plt.xlabel("rq")
plt.ylabel("elec_day")
plt.title("day_curve")
plt.xticks(rotation=60)
plt.legend()
plt.tight_layout()
plt.show()

# %%
submit = pd.read_csv("../data/temp.csv")
submit = submit[submit["label"] == 0]
submit
# Out:
#            id  label
# 0  2323237963      0

# %%
known_lst = pd.read_csv("../data/known.csv")
known_lst
# Out:
#              id  label
# 0     179569085      0
# 1    2533183958      1
# 2    2186749200      1
# 3    2533183961      0
# 4    2445049876      1
# ..          ...    ...
# 238  2274116086      0
# 239  2323184517      0
# 240  2005240319      0
# 241  2099450431      0
# 242  2724866803      0
#
# [243 rows x 2 columns]

# %%
for i in range(submit.shape[0]):
    if submit.iloc[i, 0] in known_lst["id"].values:
        continue
    print(cons_info[cons_info.index == submit.iloc[i, 0]])
    plt.figure(3 + i)
    plt.subplots(1, 2, figsize=(10, 5))
    cons_month = elec_month[elec_month["id"] == submit.iloc[i, 0]]
    cons_day = elec_day[elec_day["id"] == submit.iloc[i, 0]]
    
    ax0 = plt.subplot(1, 2, 1)
    plt.plot(cons_month["ym"], cons_month["pq_f"], color="r", label="pq_f")
    plt.plot(cons_month["ym"], cons_month["pq_g"], color="g", label="pq_g")
    plt.plot(cons_month["ym"], cons_month["pq_p"], color="b", label="pq_p")
    ax0.set_title(submit.iloc[i, 0])
    ax0.set_xlabel("ym")
    ax0.set_ylabel("elec_month")
    ax0.set_xticklabels(cons_month["ym"], rotation=60)
    ax0.legend()
    
    ax1 = plt.subplot(1, 2, 2)
    plt.plot(list(range(cons_day["kwh_pap_r2"].shape[0])), cons_day["kwh_pap_r2"], color="r", label="kwh_pap_r2")
    plt.plot(list(range(cons_day["kwh_pap_r3"].shape[0])), cons_day["kwh_pap_r3"], color="g", label="kwh_pap_r3")
    plt.plot(list(range(cons_day["kwh_pap_r3"].shape[0])), cons_day["kwh_pap_r4"], color="b", label="kwh_pap_r4")
    ax1.set_title(submit.iloc[i, 0])
    ax1.set_xlabel("rq")
    ax1.set_ylabel("elec_day")
    ax1.set_xticklabels(list(range(cons_day["kwh_pap_r2"].shape[0])), rotation=60)
    ax1.legend()
    
    plt.tight_layout()
    plt.show()
# Out:
#            ELEC_TYPE_NAME VOLT_NAME      PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 2323237963       城镇居民生活用电    交流380V  居民生活<1kV(合表)        1168.0   1168.0
#
#             SHIFT_NO         BUILD_DATE CANCEL_DATE  CHK_CYCLE LAST_CHK_DATE  \
# ID
# 2323237963       NaN  2016/12/8 8:24:00         NaN         12      2021/3/1
#
#            TMP_NAME  TMP_DATE
# ID
# 2323237963    非临时用电       NaN
