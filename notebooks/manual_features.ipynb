# %% [markdown]
# <h1>导入数据</h1>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import time
from datetime import datetime
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.utils.class_weight import compute_class_weight
from tqdm import tqdm
from time import strftime, localtime
from scipy import stats
from scipy.spatial import distance
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from joblib import dump, load

# %% [markdown]
# <h1>数据处理</h1>

# %% [markdown]
# <h2>数据预处理</h2>

# %% [markdown]
# <h3>conf_info数据预处理</h3>

# %%
cons_info = pd.read_csv("../data/训练组_比特币挖矿_档案明细（20211220）.csv", index_col=0, quotechar='"', encoding="gbk")
cons_info
# Out:
#               ID ELEC_TYPE_NAME VOLT_NAME       PRC_NAME  CONTRACT_CAP  \
#
# 1      329465205       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0
# 2      329465245       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0
# 3      329465357       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0
# 4      329465360       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           2.0
# 5      329465439       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0
# ...          ...            ...       ...            ...           ...
# 8836  2862711473       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0
# 8837  2864274650       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）          13.0
# 8838  2872313739       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0
# 8839  2872314719       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0
# 8840  2529558569       城镇居民生活用电    交流380V  居民合表电价(不满1千伏）          30.0
#
#       RUN_CAP  SHIFT_NO           BUILD_DATE CANCEL_DATE  CHK_CYCLE  \
#
# 1         4.0       1.0            2005/6/18         NaN      240.0
# 2         4.0       1.0            2005/6/18         NaN      240.0
# 3         8.0       1.0            2005/6/18         NaN      240.0
# 4         2.0       1.0            2005/6/18         NaN      240.0
# 5         8.0       1.0            2005/6/18         NaN      240.0
# ...       ...       ...                  ...         ...        ...
# 8836     39.0       NaN   2019/12/2 16:12:00         NaN      120.0
# 8837     13.0       NaN   2019/12/3 16:33:00         NaN      120.0
# 8838     39.0       NaN  2019/12/18 14:42:00         NaN      120.0
# 8839     39.0       NaN  2019/12/20 10:36:00         NaN      120.0
# 8840     30.0       NaN   2018/1/30 14:40:00         NaN      120.0
#
#             LAST_CHK_DATE TMP_NAME TMP_DATE  IS_FLAG
#
# 1               2005/6/18    非临时用电      NaN        0
# 2               2005/6/18    非临时用电      NaN        0
# 3               2005/6/18    非临时用电      NaN        0
# 4               2005/6/18    非临时用电      NaN        0
# 5               2005/6/18    非临时用电      NaN        0
# ...                   ...      ...      ...      ...
# 8836   2019/12/2 16:12:00    非临时用电      NaN        0
# 8837   2019/12/3 16:33:00    非临时用电      NaN        0
# 8838  2019/12/18 14:42:00    非临时用电      NaN        0
# 8839  2019/12/20 10:36:00    非临时用电      NaN        0
# 8840   2018/1/30 14:40:00    非临时用电      NaN        0
#
# [8840 rows x 14 columns]

# %%
cons_info = cons_info.set_index("ID").drop(columns=["CANCEL_DATE", "TMP_DATE"])
cons_info
# Out:
#            ELEC_TYPE_NAME VOLT_NAME       PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 329465205        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465245        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465357        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# 329465360        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           2.0      2.0
# 329465439        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# ...                   ...       ...            ...           ...      ...
# 2862711473       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2864274650       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）          13.0     13.0
# 2872313739       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2872314719       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2529558569       城镇居民生活用电    交流380V  居民合表电价(不满1千伏）          30.0     30.0
#
#             SHIFT_NO           BUILD_DATE  CHK_CYCLE        LAST_CHK_DATE  \
# ID
# 329465205        1.0            2005/6/18      240.0            2005/6/18
# 329465245        1.0            2005/6/18      240.0            2005/6/18
# 329465357        1.0            2005/6/18      240.0            2005/6/18
# 329465360        1.0            2005/6/18      240.0            2005/6/18
# 329465439        1.0            2005/6/18      240.0            2005/6/18
# ...              ...                  ...        ...                  ...
# 2862711473       NaN   2019/12/2 16:12:00      120.0   2019/12/2 16:12:00
# 2864274650       NaN   2019/12/3 16:33:00      120.0   2019/12/3 16:33:00
# 2872313739       NaN  2019/12/18 14:42:00      120.0  2019/12/18 14:42:00
# 2872314719       NaN  2019/12/20 10:36:00      120.0  2019/12/20 10:36:00
# 2529558569       NaN   2018/1/30 14:40:00      120.0   2018/1/30 14:40:00
#
#            TMP_NAME  IS_FLAG
# ID
# 329465205     非临时用电        0
# 329465245     非临时用电        0
# 329465357     非临时用电        0
# 329465360     非临时用电        0
# 329465439     非临时用电        0
# ...             ...      ...
# 2862711473    非临时用电        0
# 2864274650    非临时用电        0
# 2872313739    非临时用电        0
# 2872314719    非临时用电        0
# 2529558569    非临时用电        0
#
# [8840 rows x 11 columns]

# %%
cons_info["BUILD_DATE"] = pd.to_datetime(cons_info["BUILD_DATE"])
cons_info["LAST_CHK_DATE"] = pd.to_datetime(cons_info["LAST_CHK_DATE"])
cons_info
# Out:
#            ELEC_TYPE_NAME VOLT_NAME       PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 329465205        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465245        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465357        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# 329465360        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           2.0      2.0
# 329465439        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# ...                   ...       ...            ...           ...      ...
# 2862711473       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2864274650       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）          13.0     13.0
# 2872313739       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2872314719       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2529558569       城镇居民生活用电    交流380V  居民合表电价(不满1千伏）          30.0     30.0
#
#             SHIFT_NO          BUILD_DATE  CHK_CYCLE       LAST_CHK_DATE  \
# ID
# 329465205        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465245        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465357        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465360        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465439        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# ...              ...                 ...        ...                 ...
# 2862711473       NaN 2019-12-02 16:12:00      120.0 2019-12-02 16:12:00
# 2864274650       NaN 2019-12-03 16:33:00      120.0 2019-12-03 16:33:00
# 2872313739       NaN 2019-12-18 14:42:00      120.0 2019-12-18 14:42:00
# 2872314719       NaN 2019-12-20 10:36:00      120.0 2019-12-20 10:36:00
# 2529558569       NaN 2018-01-30 14:40:00      120.0 2018-01-30 14:40:00
#
#            TMP_NAME  IS_FLAG
# ID
# 329465205     非临时用电        0
# 329465245     非临时用电        0
# 329465357     非临时用电        0
# 329465360     非临时用电        0
# 329465439     非临时用电        0
# ...             ...      ...
# 2862711473    非临时用电        0
# 2864274650    非临时用电        0
# 2872313739    非临时用电        0
# 2872314719    非临时用电        0
# 2529558569    非临时用电        0
#
# [8840 rows x 11 columns]

# %%
cons_info["SHIFT_NO"] = cons_info["SHIFT_NO"].fillna(0)
cons_info
# Out:
#            ELEC_TYPE_NAME VOLT_NAME       PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 329465205        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465245        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465357        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# 329465360        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           2.0      2.0
# 329465439        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# ...                   ...       ...            ...           ...      ...
# 2862711473       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2864274650       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）          13.0     13.0
# 2872313739       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2872314719       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2529558569       城镇居民生活用电    交流380V  居民合表电价(不满1千伏）          30.0     30.0
#
#             SHIFT_NO          BUILD_DATE  CHK_CYCLE       LAST_CHK_DATE  \
# ID
# 329465205        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465245        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465357        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465360        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465439        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# ...              ...                 ...        ...                 ...
# 2862711473       0.0 2019-12-02 16:12:00      120.0 2019-12-02 16:12:00
# 2864274650       0.0 2019-12-03 16:33:00      120.0 2019-12-03 16:33:00
# 2872313739       0.0 2019-12-18 14:42:00      120.0 2019-12-18 14:42:00
# 2872314719       0.0 2019-12-20 10:36:00      120.0 2019-12-20 10:36:00
# 2529558569       0.0 2018-01-30 14:40:00      120.0 2018-01-30 14:40:00
#
#            TMP_NAME  IS_FLAG
# ID
# 329465205     非临时用电        0
# 329465245     非临时用电        0
# 329465357     非临时用电        0
# 329465360     非临时用电        0
# 329465439     非临时用电        0
# ...             ...      ...
# 2862711473    非临时用电        0
# 2864274650    非临时用电        0
# 2872313739    非临时用电        0
# 2872314719    非临时用电        0
# 2529558569    非临时用电        0
#
# [8840 rows x 11 columns]

# %%
cons_info["now"] = "2021-12-31"
cons_info["now"] = pd.to_datetime(cons_info["now"])
cons_info
# Out:
#            ELEC_TYPE_NAME VOLT_NAME       PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 329465205        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465245        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465357        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# 329465360        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           2.0      2.0
# 329465439        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# ...                   ...       ...            ...           ...      ...
# 2862711473       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2864274650       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）          13.0     13.0
# 2872313739       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2872314719       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2529558569       城镇居民生活用电    交流380V  居民合表电价(不满1千伏）          30.0     30.0
#
#             SHIFT_NO          BUILD_DATE  CHK_CYCLE       LAST_CHK_DATE  \
# ID
# 329465205        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465245        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465357        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465360        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465439        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# ...              ...                 ...        ...                 ...
# 2862711473       0.0 2019-12-02 16:12:00      120.0 2019-12-02 16:12:00
# 2864274650       0.0 2019-12-03 16:33:00      120.0 2019-12-03 16:33:00
# 2872313739       0.0 2019-12-18 14:42:00      120.0 2019-12-18 14:42:00
# 2872314719       0.0 2019-12-20 10:36:00      120.0 2019-12-20 10:36:00
# 2529558569       0.0 2018-01-30 14:40:00      120.0 2018-01-30 14:40:00
#
#            TMP_NAME  IS_FLAG        now
# ID
# 329465205     非临时用电        0 2021-12-31
# 329465245     非临时用电        0 2021-12-31
# 329465357     非临时用电        0 2021-12-31
# 329465360     非临时用电        0 2021-12-31
# 329465439     非临时用电        0 2021-12-31
# ...             ...      ...        ...
# 2862711473    非临时用电        0 2021-12-31
# 2864274650    非临时用电        0 2021-12-31
# 2872313739    非临时用电        0 2021-12-31
# 2872314719    非临时用电        0 2021-12-31
# 2529558569    非临时用电        0 2021-12-31
#
# [8840 rows x 12 columns]

# %%
cons_info["live_days"] = (cons_info["now"] - cons_info["BUILD_DATE"]).map(lambda x: x.days)
cons_info["check_days"] = (cons_info["now"] - cons_info["LAST_CHK_DATE"]).map(lambda x: x.days)
cons_info
# Out:
#            ELEC_TYPE_NAME VOLT_NAME       PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 329465205        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465245        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465357        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# 329465360        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           2.0      2.0
# 329465439        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# ...                   ...       ...            ...           ...      ...
# 2862711473       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2864274650       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）          13.0     13.0
# 2872313739       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2872314719       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2529558569       城镇居民生活用电    交流380V  居民合表电价(不满1千伏）          30.0     30.0
#
#             SHIFT_NO          BUILD_DATE  CHK_CYCLE       LAST_CHK_DATE  \
# ID
# 329465205        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465245        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465357        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465360        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# 329465439        1.0 2005-06-18 00:00:00      240.0 2005-06-18 00:00:00
# ...              ...                 ...        ...                 ...
# 2862711473       0.0 2019-12-02 16:12:00      120.0 2019-12-02 16:12:00
# 2864274650       0.0 2019-12-03 16:33:00      120.0 2019-12-03 16:33:00
# 2872313739       0.0 2019-12-18 14:42:00      120.0 2019-12-18 14:42:00
# 2872314719       0.0 2019-12-20 10:36:00      120.0 2019-12-20 10:36:00
# 2529558569       0.0 2018-01-30 14:40:00      120.0 2018-01-30 14:40:00
#
#            TMP_NAME  IS_FLAG        now  live_days  check_days
# ID
# 329465205     非临时用电        0 2021-12-31       6040        6040
# 329465245     非临时用电        0 2021-12-31       6040        6040
# 329465357     非临时用电        0 2021-12-31       6040        6040
# 329465360     非临时用电        0 2021-12-31       6040        6040
# 329465439     非临时用电        0 2021-12-31       6040        6040
# ...             ...      ...        ...        ...         ...
# 2862711473    非临时用电        0 2021-12-31        759         759
# 2864274650    非临时用电        0 2021-12-31        758         758
# 2872313739    非临时用电        0 2021-12-31        743         743
# 2872314719    非临时用电        0 2021-12-31        741         741
# 2529558569    非临时用电        0 2021-12-31       1430        1430
#
# [8840 rows x 14 columns]

# %%
cons_info = cons_info.drop(columns=["BUILD_DATE", "LAST_CHK_DATE", "now"])
cons_info
# Out:
#            ELEC_TYPE_NAME VOLT_NAME       PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 329465205        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465245        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           4.0      4.0
# 329465357        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# 329465360        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           2.0      2.0
# 329465439        乡村居民生活用电    交流220V  居民合表电价(不满1千伏）           8.0      8.0
# ...                   ...       ...            ...           ...      ...
# 2862711473       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2864274650       乡村居民生活用电    交流220V  居民合表电价(不满1千伏）          13.0     13.0
# 2872313739       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2872314719       乡村居民生活用电    交流380V  居民合表电价(不满1千伏）          39.0     39.0
# 2529558569       城镇居民生活用电    交流380V  居民合表电价(不满1千伏）          30.0     30.0
#
#             SHIFT_NO  CHK_CYCLE TMP_NAME  IS_FLAG  live_days  check_days
# ID
# 329465205        1.0      240.0    非临时用电        0       6040        6040
# 329465245        1.0      240.0    非临时用电        0       6040        6040
# 329465357        1.0      240.0    非临时用电        0       6040        6040
# 329465360        1.0      240.0    非临时用电        0       6040        6040
# 329465439        1.0      240.0    非临时用电        0       6040        6040
# ...              ...        ...      ...      ...        ...         ...
# 2862711473       0.0      120.0    非临时用电        0        759         759
# 2864274650       0.0      120.0    非临时用电        0        758         758
# 2872313739       0.0      120.0    非临时用电        0        743         743
# 2872314719       0.0      120.0    非临时用电        0        741         741
# 2529558569       0.0      120.0    非临时用电        0       1430        1430
#
# [8840 rows x 11 columns]

# %%
cons_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8840 entries, 329465205 to 2529558569
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ELEC_TYPE_NAME  8840 non-null   object
#  1   VOLT_NAME       8840 non-null   object
#  2   PRC_NAME        8840 non-null   object
#  3   CONTRACT_CAP    8840 non-null   float64
#  4   RUN_CAP         8840 non-null   float64
#  5   SHIFT_NO        8840 non-null   float64
#  6   CHK_CYCLE       8838 non-null   float64
#  7   TMP_NAME        8840 non-null   object
#  8   IS_FLAG         8840 non-null   int64
#  9   live_days       8840 non-null   int64
#  10  check_days      8840 non-null   int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 828.8+ KB

# %%
cons_info = pd.get_dummies(cons_info)
cons_info
# Out:
#             CONTRACT_CAP  RUN_CAP  SHIFT_NO  CHK_CYCLE  IS_FLAG  live_days  \
# ID
# 329465205            4.0      4.0       1.0      240.0        0       6040
# 329465245            4.0      4.0       1.0      240.0        0       6040
# 329465357            8.0      8.0       1.0      240.0        0       6040
# 329465360            2.0      2.0       1.0      240.0        0       6040
# 329465439            8.0      8.0       1.0      240.0        0       6040
# ...                  ...      ...       ...        ...      ...        ...
# 2862711473          39.0     39.0       0.0      120.0        0        759
# 2864274650          13.0     13.0       0.0      120.0        0        758
# 2872313739          39.0     39.0       0.0      120.0        0        743
# 2872314719          39.0     39.0       0.0      120.0        0        741
# 2529558569          30.0     30.0       0.0      120.0        0       1430
#
#             check_days  ELEC_TYPE_NAME_乡村居民生活用电  ELEC_TYPE_NAME_商业用电  \
# ID
# 329465205         6040                        1                    0
# 329465245         6040                        1                    0
# 329465357         6040                        1                    0
# 329465360         6040                        1                    0
# 329465439         6040                        1                    0
# ...                ...                      ...                  ...
# 2862711473         759                        1                    0
# 2864274650         758                        1                    0
# 2872313739         743                        1                    0
# 2872314719         741                        1                    0
# 2529558569        1430                        0                    0
#
#             ELEC_TYPE_NAME_城镇居民生活用电  ...  ELEC_TYPE_NAME_居民生活用电  \
# ID                                   ...
# 329465205                         0  ...                      0
# 329465245                         0  ...                      0
# 329465357                         0  ...                      0
# 329465360                         0  ...                      0
# 329465439                         0  ...                      0
# ...                             ...  ...                    ...
# 2862711473                        0  ...                      0
# 2864274650                        0  ...                      0
# 2872313739                        0  ...                      0
# 2872314719                        0  ...                      0
# 2529558569                        1  ...                      0
#
#             ELEC_TYPE_NAME_普通工业  ELEC_TYPE_NAME_非居民照明  ELEC_TYPE_NAME_非工业  \
# ID
# 329465205                     0                     0                   0
# 329465245                     0                     0                   0
# 329465357                     0                     0                   0
# 329465360                     0                     0                   0
# 329465439                     0                     0                   0
# ...                         ...                   ...                 ...
# 2862711473                    0                     0                   0
# 2864274650                    0                     0                   0
# 2872313739                    0                     0                   0
# 2872314719                    0                     0                   0
# 2529558569                    0                     0                   0
#
#             VOLT_NAME_交流10kV  VOLT_NAME_交流220V  VOLT_NAME_交流380V  \
# ID
# 329465205                  0                 1                 0
# 329465245                  0                 1                 0
# 329465357                  0                 1                 0
# 329465360                  0                 1                 0
# 329465439                  0                 1                 0
# ...                      ...               ...               ...
# 2862711473                 0                 0                 1
# 2864274650                 0                 1                 0
# 2872313739                 0                 0                 1
# 2872314719                 0                 0                 1
# 2529558569                 0                 0                 1
#
#             PRC_NAME_居民合表电价(1-10千伏）  PRC_NAME_居民合表电价(不满1千伏）  TMP_NAME_非临时用电
# ID
# 329465205                         0                       1               1
# 329465245                         0                       1               1
# 329465357                         0                       1               1
# 329465360                         0                       1               1
# 329465439                         0                       1               1
# ...                             ...                     ...             ...
# 2862711473                        0                       1               1
# 2864274650                        0                       1               1
# 2872313739                        0                       1               1
# 2872314719                        0                       1               1
# 2529558569                        0                       1               1
#
# [8840 rows x 21 columns]

# %%
cons_info["CHK_CYCLE"] = cons_info["CHK_CYCLE"].fillna(cons_info["CHK_CYCLE"].median())
cons_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8840 entries, 329465205 to 2529558569
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CONTRACT_CAP                8840 non-null   float64
#  1   RUN_CAP                     8840 non-null   float64
#  2   SHIFT_NO                    8840 non-null   float64
#  3   CHK_CYCLE                   8840 non-null   float64
#  4   IS_FLAG                     8840 non-null   int64
#  5   live_days                   8840 non-null   int64
#  6   check_days                  8840 non-null   int64
#  7   ELEC_TYPE_NAME_乡村居民生活用电     8840 non-null   uint8
#  8   ELEC_TYPE_NAME_商业用电         8840 non-null   uint8
#  9   ELEC_TYPE_NAME_城镇居民生活用电     8840 non-null   uint8
#  10  ELEC_TYPE_NAME_学校教学和学生生活用电  8840 non-null   uint8
#  11  ELEC_TYPE_NAME_居民生活用电       8840 non-null   uint8
#  12  ELEC_TYPE_NAME_普通工业         8840 non-null   uint8
#  13  ELEC_TYPE_NAME_非居民照明        8840 non-null   uint8
#  14  ELEC_TYPE_NAME_非工业          8840 non-null   uint8
#  15  VOLT_NAME_交流10kV            8840 non-null   uint8
#  16  VOLT_NAME_交流220V            8840 non-null   uint8
#  17  VOLT_NAME_交流380V            8840 non-null   uint8
#  18  PRC_NAME_居民合表电价(1-10千伏）     8840 non-null   uint8
#  19  PRC_NAME_居民合表电价(不满1千伏）      8840 non-null   uint8
#  20  TMP_NAME_非临时用电              8840 non-null   uint8
# dtypes: float64(4), int64(3), uint8(14)
# memory usage: 673.4 KB

# %% [markdown]
# <h3>elec_month数据预处理</h3>

# %%
cons_info["pq_z_mean"] = 0
cons_info["pq_z_median"] = 0
cons_info["pq_z_std"] = 0
cons_info["pq_z_std/mean"] = 0
cons_info["pq_z_entropy"] = 0
cons_info["pq_fg_distance"] = 0
cons_info["pq_gp_diatance"] = 0
cons_info["pq_fp_distance"] = 0
cons_info["pq_fg_cosine"] = 0
cons_info["pq_gp_cosine"] = 0
cons_info["pq_fp_cosine"] = 0
cons_info["pq_fz_cosine"] = 0
cons_info["pq_gz_cosine"] = 0
cons_info["pq_pz_cosine"] = 0

# %%
def entropy(data, bins: int = 10) -> float:
    """
    计算一个序列的熵\n
    """
    nums = np.histogram(data, bins=bins)[0]
    probs = nums / sum(nums)
    return stats.entropy(probs)

# %%
def cosine(a, b) -> float:
    """
    计算余弦距离\n
    """
    if np.linalg.norm(a) != 0 and np.linalg.norm(b) != 0:
        return distance.cosine(a, b)
    elif np.linalg.norm(a) == 0 and np.linalg.norm(b) == 0:
        return 0
    else:
        return 1

# %%
elec_month = pd.read_csv("../data/训练组_比特币挖矿_月用电明细（20211217）.csv")
elec_month
# Out:
#                 id      ym  pq_f  pq_g  pq_p  pq_z
# 0        329769614  202001   615   161     0   776
# 1        329769614  202002   492   154    -1   645
# 2        329769614  202003   457   114     1   572
# 3        329769614  202004   522   171     0   693
# 4        329769614  202005   519   181     0   700
# ...            ...     ...   ...   ...   ...   ...
# 194475  2878334859  202106   107    67    -1   173
# 194476  2878334859  202107   170   112     1   283
# 194477  2878334859  202108   102    67     0   169
# 194478  2878334859  202109   112    65    -1   176
# 194479  2878334859  202110   144    84     1   229
#
# [194480 rows x 6 columns]

# %%
elec_month["ym"] = elec_month["ym"].astype(str)
elec_month
# Out:
#                 id      ym  pq_f  pq_g  pq_p  pq_z
# 0        329769614  202001   615   161     0   776
# 1        329769614  202002   492   154    -1   645
# 2        329769614  202003   457   114     1   572
# 3        329769614  202004   522   171     0   693
# 4        329769614  202005   519   181     0   700
# ...            ...     ...   ...   ...   ...   ...
# 194475  2878334859  202106   107    67    -1   173
# 194476  2878334859  202107   170   112     1   283
# 194477  2878334859  202108   102    67     0   169
# 194478  2878334859  202109   112    65    -1   176
# 194479  2878334859  202110   144    84     1   229
#
# [194480 rows x 6 columns]

# %%
for cons_id in tqdm(cons_info.index):
    df = elec_month[elec_month["id"] == cons_id]
    df = df.drop(columns=["id"]).sort_values("ym").set_index("ym")
    df = df.fillna(method="ffill").fillna(method="bfill")
    cons_info.loc[cons_id, "pq_z_mean"] = df["pq_z"].mean()
    cons_info.loc[cons_id, "pq_z_median"] = df["pq_z"].median()
    cons_info.loc[cons_id, "pq_z_std"] = df["pq_z"].std()
    cons_info.loc[(cons_info.index == cons_id) & (cons_info["pq_z_mean"] > 0), "pq_z_std/mean"] = cons_info["pq_z_std"] / cons_info["pq_z_mean"]
    cons_info.loc[cons_id, "pq_z_entropy"] = entropy(df["pq_z"])
    cons_info.loc[cons_id, "pq_fg_distance"] = distance.euclidean(df["pq_f"], df["pq_g"])
    cons_info.loc[cons_id, "pq_gp_diatance"] = distance.euclidean(df["pq_g"], df["pq_p"])
    cons_info.loc[cons_id, "pq_fp_distance"] = distance.euclidean(df["pq_f"], df["pq_p"])
    cons_info.loc[cons_id, "pq_fg_cosine"] = cosine(df["pq_f"], df["pq_g"])
    cons_info.loc[cons_id, "pq_gp_cosine"] = cosine(df["pq_g"], df["pq_p"])
    cons_info.loc[cons_id, "pq_fp_cosine"] = cosine(df["pq_f"], df["pq_p"])
    cons_info.loc[cons_id, "pq_fz_cosine"] = cosine(df["pq_f"], df["pq_z"])
    cons_info.loc[cons_id, "pq_gz_cosine"] = cosine(df["pq_g"], df["pq_z"])
    cons_info.loc[cons_id, "pq_pz_cosine"] = cosine(df["pq_p"], df["pq_z"])
    
cons_info
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 8840/8840 [00:55<00:00, 158.15it/s]
#             CONTRACT_CAP  RUN_CAP  SHIFT_NO  CHK_CYCLE  IS_FLAG  live_days  \
# ID
# 329465205            4.0      4.0       1.0      240.0        0       6040
# 329465245            4.0      4.0       1.0      240.0        0       6040
# 329465357            8.0      8.0       1.0      240.0        0       6040
# 329465360            2.0      2.0       1.0      240.0        0       6040
# 329465439            8.0      8.0       1.0      240.0        0       6040
# ...                  ...      ...       ...        ...      ...        ...
# 2862711473          39.0     39.0       0.0      120.0        0        759
# 2864274650          13.0     13.0       0.0      120.0        0        758
# 2872313739          39.0     39.0       0.0      120.0        0        743
# 2872314719          39.0     39.0       0.0      120.0        0        741
# 2529558569          30.0     30.0       0.0      120.0        0       1430
#
#             check_days  ELEC_TYPE_NAME_乡村居民生活用电  ELEC_TYPE_NAME_商业用电  \
# ID
# 329465205         6040                        1                    0
# 329465245         6040                        1                    0
# 329465357         6040                        1                    0
# 329465360         6040                        1                    0
# 329465439         6040                        1                    0
# ...                ...                      ...                  ...
# 2862711473         759                        1                    0
# 2864274650         758                        1                    0
# 2872313739         743                        1                    0
# 2872314719         741                        1                    0
# 2529558569        1430                        0                    0
#
#             ELEC_TYPE_NAME_城镇居民生活用电  ...  pq_z_entropy  pq_fg_distance  \
# ID                                   ...
# 329465205                         0  ...      2.074490     1100.455815
# 329465245                         0  ...      1.652715     1884.471013
# 329465357                         0  ...      1.360200     1005.509821
# 329465360                         0  ...      1.693263     2167.596826
# 329465439                         0  ...      1.288252        0.000000
# ...                             ...  ...           ...             ...
# 2862711473                        0  ...      1.858519     2535.397208
# 2864274650                        0  ...      1.306844     1174.220593
# 2872313739                        0  ...      0.367649        8.944272
# 2872314719                        0  ...      0.948588      876.982896
# 2529558569                        1  ...      1.209928     1476.010501
#
#             pq_gp_diatance  pq_fp_distance  pq_fg_cosine  pq_gp_cosine  \
# ID
# 329465205      1368.865223     2425.555813      0.014260      1.030399
# 329465245      1641.545004     3495.833377      0.009833      1.049541
# 329465357      7926.527613     7997.614144      0.000281      0.949959
# 329465360      1586.905164     3726.984304      0.010028      0.850390
# 329465439      5675.094449     5675.094449      0.000000      1.000000
# ...                    ...             ...           ...           ...
# 2862711473     2653.334506     5183.746811      0.000915      1.078510
# 2864274650      855.526154     2021.216218      0.005729      1.143152
# 2872313739        1.000000        9.848858      0.086188      1.000000
# 2872314719      359.676243     1158.555135      0.156956      0.912936
# 2529558569     1039.379142     2505.875895      0.005390      1.071378
#
#             pq_fp_cosine  pq_fz_cosine  pq_gz_cosine  pq_pz_cosine
# ID
# 329465205       1.069618      0.001869      0.005819      1.054778
# 329465245       1.049255      0.001004      0.004561      1.048902
# 329465357       0.947601      0.711070      0.713365      0.028826
# 329465360       0.860356      0.000896      0.004936      0.856495
# 329465439       1.000000      1.000000      1.000000      0.000000
# ...                  ...           ...           ...           ...
# 2862711473      1.073679      0.000104      0.000402      1.074872
# 2864274650      1.123854      0.000500      0.002849      1.128561
# 2872313739      1.000000      0.000711      0.071523      1.000000
# 2872314719      0.925805      0.008666      0.093620      0.918036
# 2529558569      1.079902      0.000466      0.002690      1.076559
#
# [8840 rows x 35 columns]

# %% [markdown]
# <h3>elec_day数据预处理</h3>

# %%
cons_info["kwh_mean"] = 0
cons_info["kwh_median"] = 0
cons_info["kwh_std"] = 0
cons_info["kwh_std/mean"] = 0
cons_info["kwh_entropy"] = 0
cons_info["kwh_pap_r12_distance"] = 0
cons_info["kwh_pap_r13_distance"] = 0
cons_info["kwh_pap_r14_distance"] = 0
cons_info["kwh_pap_r23_distance"] = 0
cons_info["kwh_pap_r24_distance"] = 0
cons_info["kwh_pap_r34_distance"] = 0
cons_info["kwh_pap_r12_cosine"] = 0
cons_info["kwh_pap_r13_cosine"] = 0
cons_info["kwh_pap_r14_cosine"] = 0
cons_info["kwh_pap_r23_cosine"] = 0
cons_info["kwh_pap_r24_cosine"] = 0
cons_info["kwh_pap_r34_cosine"] = 0
cons_info["kwh_pap_r1_cosine"] = 0
cons_info["kwh_pap_r2_cosine"] = 0
cons_info["kwh_pap_r3_cosine"] = 0
cons_info["kwh_pap_r4_cosine"] = 0

# %%
elec_day = pd.read_csv("../data/训练组_比特币挖矿_日用电明细（20211217）.csv")
elec_day
# Out:
#                 id                   rq    kwh  kwh_rap  kwh_pap_r1  \
# 0        329449398  2020-01-22 00:00:00  11.77      0.0         0.0
# 1        329449398  2020-01-23 00:00:00  16.54      0.0         0.0
# 2        329449398  2020-01-24 00:00:00  10.86      0.0         0.0
# 3        329449398  2020-01-25 00:00:00  10.91      0.0         0.0
# 4        329449398  2020-01-26 00:00:00  10.85      0.0         0.0
# ...            ...                  ...    ...      ...         ...
# 954564  2878334859  2021-10-05 00:00:00   7.22      NaN         0.0
# 954565  2878334859  2021-10-06 00:00:00   7.23      NaN         0.0
# 954566  2878334859  2021-10-07 00:00:00   7.20      NaN         0.0
# 954567  2878334859  2021-10-08 00:00:00   7.23      NaN         0.0
# 954568  2878334859  2021-10-09 00:00:00   7.22      NaN         0.0
#
#         kwh_pap_r2  kwh_pap_r3  kwh_pap_r4
# 0             7.40         0.0        4.36
# 1             8.68         0.0        7.86
# 2             5.51         0.0        5.36
# 3             6.48         0.0        4.43
# 4             6.32         0.0        4.52
# ...            ...         ...         ...
# 954564        4.49         0.0        2.73
# 954565        4.48         0.0        2.74
# 954566        4.48         0.0        2.73
# 954567        4.50         0.0        2.73
# 954568        4.48         0.0        2.73
#
# [954569 rows x 8 columns]

# %%
elec_day["rq"] = pd.to_datetime(elec_day["rq"])
elec_day
# Out:
#                 id         rq    kwh  kwh_rap  kwh_pap_r1  kwh_pap_r2  \
# 0        329449398 2020-01-22  11.77      0.0         0.0        7.40
# 1        329449398 2020-01-23  16.54      0.0         0.0        8.68
# 2        329449398 2020-01-24  10.86      0.0         0.0        5.51
# 3        329449398 2020-01-25  10.91      0.0         0.0        6.48
# 4        329449398 2020-01-26  10.85      0.0         0.0        6.32
# ...            ...        ...    ...      ...         ...         ...
# 954564  2878334859 2021-10-05   7.22      NaN         0.0        4.49
# 954565  2878334859 2021-10-06   7.23      NaN         0.0        4.48
# 954566  2878334859 2021-10-07   7.20      NaN         0.0        4.48
# 954567  2878334859 2021-10-08   7.23      NaN         0.0        4.50
# 954568  2878334859 2021-10-09   7.22      NaN         0.0        4.48
#
#         kwh_pap_r3  kwh_pap_r4
# 0              0.0        4.36
# 1              0.0        7.86
# 2              0.0        5.36
# 3              0.0        4.43
# 4              0.0        4.52
# ...            ...         ...
# 954564         0.0        2.73
# 954565         0.0        2.74
# 954566         0.0        2.73
# 954567         0.0        2.73
# 954568         0.0        2.73
#
# [954569 rows x 8 columns]

# %%
for cons_id in tqdm(cons_info.index):
    df = elec_day[elec_day["id"] == cons_id]
    df = df.drop(columns=["id"]).sort_values("rq").set_index("rq")
    df = df.fillna(method="ffill").fillna(method="bfill")
    cons_info.loc[cons_id, "kwh_mean"] = df["kwh"].mean()
    cons_info.loc[cons_id, "kwh_median"] = df["kwh"].median()
    cons_info.loc[cons_id, "kwh_std"] = df["kwh"].std()
    cons_info.loc[(cons_info.index == cons_id) & (cons_info["kwh_mean"] > 0), "kwh_std/mean"] = cons_info["kwh_std"] / cons_info["kwh_mean"]
    cons_info.loc[cons_id, "kwh_entropy"] = entropy(df["kwh"])
    cons_info.loc[cons_id, "kwh_pap_r12_distance"] = distance.euclidean(df["kwh_pap_r1"], df["kwh_pap_r2"])
    cons_info.loc[cons_id, "kwh_pap_r13_distance"] = distance.euclidean(df["kwh_pap_r1"], df["kwh_pap_r3"])
    cons_info.loc[cons_id, "kwh_pap_r14_distance"] = distance.euclidean(df["kwh_pap_r1"], df["kwh_pap_r4"])
    cons_info.loc[cons_id, "kwh_pap_r23_distance"] = distance.euclidean(df["kwh_pap_r2"], df["kwh_pap_r3"])
    cons_info.loc[cons_id, "kwh_pap_r24_distance"] = distance.euclidean(df["kwh_pap_r2"], df["kwh_pap_r4"])
    cons_info.loc[cons_id, "kwh_pap_r34_distance"] = distance.euclidean(df["kwh_pap_r3"], df["kwh_pap_r4"])

    cons_info.loc[cons_id, "kwh_pap_r12_cosine"] = cosine(df["kwh_pap_r1"], df["kwh_pap_r2"])
    cons_info.loc[cons_id, "kwh_pap_r13_cosine"] = cosine(df["kwh_pap_r1"], df["kwh_pap_r3"])
    cons_info.loc[cons_id, "kwh_pap_r14_cosine"] = cosine(df["kwh_pap_r1"], df["kwh_pap_r4"])
    cons_info.loc[cons_id, "kwh_pap_r23_cosine"] = cosine(df["kwh_pap_r2"], df["kwh_pap_r3"])
    cons_info.loc[cons_id, "kwh_pap_r24_cosine"] = cosine(df["kwh_pap_r2"], df["kwh_pap_r4"])
    cons_info.loc[cons_id, "kwh_pap_r34_cosine"] = cosine(df["kwh_pap_r3"], df["kwh_pap_r4"])
    
    cons_info.loc[cons_id, "kwh_pap_r1_cosine"] = cosine(df["kwh_pap_r1"], df["kwh"])
    cons_info.loc[cons_id, "kwh_pap_r2_cosine"] = cosine(df["kwh_pap_r2"], df["kwh"])
    cons_info.loc[cons_id, "kwh_pap_r3_cosine"] = cosine(df["kwh_pap_r3"], df["kwh"])
    cons_info.loc[cons_id, "kwh_pap_r4_cosine"] = cosine(df["kwh_pap_r4"], df["kwh"])
    
cons_info
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 8840/8840 [01:18<00:00, 112.80it/s]
#             CONTRACT_CAP  RUN_CAP  SHIFT_NO  CHK_CYCLE  IS_FLAG  live_days  \
# ID
# 329465205            4.0      4.0       1.0      240.0        0       6040
# 329465245            4.0      4.0       1.0      240.0        0       6040
# 329465357            8.0      8.0       1.0      240.0        0       6040
# 329465360            2.0      2.0       1.0      240.0        0       6040
# 329465439            8.0      8.0       1.0      240.0        0       6040
# ...                  ...      ...       ...        ...      ...        ...
# 2862711473          39.0     39.0       0.0      120.0        0        759
# 2864274650          13.0     13.0       0.0      120.0        0        758
# 2872313739          39.0     39.0       0.0      120.0        0        743
# 2872314719          39.0     39.0       0.0      120.0        0        741
# 2529558569          30.0     30.0       0.0      120.0        0       1430
#
#             check_days  ELEC_TYPE_NAME_乡村居民生活用电  ELEC_TYPE_NAME_商业用电  \
# ID
# 329465205         6040                        1                    0
# 329465245         6040                        1                    0
# 329465357         6040                        1                    0
# 329465360         6040                        1                    0
# 329465439         6040                        1                    0
# ...                ...                      ...                  ...
# 2862711473         759                        1                    0
# 2864274650         758                        1                    0
# 2872313739         743                        1                    0
# 2872314719         741                        1                    0
# 2529558569        1430                        0                    0
#
#             ELEC_TYPE_NAME_城镇居民生活用电  ...  kwh_pap_r12_cosine  \
# ID                                   ...
# 329465205                         0  ...                 1.0
# 329465245                         0  ...                 1.0
# 329465357                         0  ...                 1.0
# 329465360                         0  ...                 1.0
# 329465439                         0  ...                 1.0
# ...                             ...  ...                 ...
# 2862711473                        0  ...                 1.0
# 2864274650                        0  ...                 1.0
# 2872313739                        0  ...                 0.0
# 2872314719                        0  ...                 1.0
# 2529558569                        1  ...                 1.0
#
#             kwh_pap_r13_cosine  kwh_pap_r14_cosine  kwh_pap_r23_cosine  \
# ID
# 329465205                  0.0                 1.0                 1.0
# 329465245                  0.0                 1.0                 1.0
# 329465357                  0.0                 1.0                 1.0
# 329465360                  0.0                 1.0                 1.0
# 329465439                  0.0                 1.0                 1.0
# ...                        ...                 ...                 ...
# 2862711473                 0.0                 1.0                 1.0
# 2864274650                 0.0                 1.0                 1.0
# 2872313739                 0.0                 0.0                 0.0
# 2872314719                 0.0                 1.0                 1.0
# 2529558569                 0.0                 1.0                 1.0
#
#             kwh_pap_r24_cosine  kwh_pap_r34_cosine  kwh_pap_r1_cosine  \
# ID
# 329465205             0.112179                 1.0                1.0
# 329465245             0.042256                 1.0                1.0
# 329465357             0.039354                 1.0                1.0
# 329465360             0.034102                 1.0                1.0
# 329465439             0.045007                 1.0                1.0
# ...                        ...                 ...                ...
# 2862711473            0.046646                 1.0                1.0
# 2864274650            0.027986                 1.0                1.0
# 2872313739            0.000000                 0.0                0.0
# 2872314719            0.220609                 1.0                1.0
# 2529558569            0.008171                 1.0                1.0
#
#             kwh_pap_r2_cosine  kwh_pap_r3_cosine  kwh_pap_r4_cosine
# ID
# 329465205            0.013884                1.0           0.048088
# 329465245            0.004351                1.0           0.019658
# 329465357            0.001687                1.0           0.024876
# 329465360            0.002899                1.0           0.017558
# 329465439            0.003703                1.0           0.023050
# ...                       ...                ...                ...
# 2862711473           0.005853                1.0           0.019615
# 2864274650           0.002854                1.0           0.013023
# 2872313739           0.000000                0.0           0.000000
# 2872314719           0.011304                1.0           0.135482
# 2529558569           0.000703                1.0           0.004179
#
# [8840 rows x 56 columns]

# %% [markdown]
# <h2>数据集划分</h2>

# %%
x = cons_info.drop(columns=["IS_FLAG"])
y = cons_info["IS_FLAG"]
print(x.shape, y.shape)
# Out:
# (8840, 55) (8840,)

# %% [markdown]
# <h2>标准化</h2>

# %%
ss = StandardScaler()
x = ss.fit_transform(x)
x
# Out:
# array([[-0.31260749, -0.31917163,  1.05812375, ..., -0.19819297,
#          0.53828596, -0.16223824],
#        [-0.31260749, -0.31917163,  1.05812375, ..., -0.25703545,
#          0.53828596, -0.31772669],
#        [-0.2464131 , -0.25086739,  1.05812375, ..., -0.27347857,
#          0.53828596, -0.28918791],
#        ...,
#        [ 0.2665934 ,  0.27849043, -0.86811471, ..., -0.2838904 ,
#         -1.93452962, -0.42523935],
#        [ 0.2665934 ,  0.27849043, -0.86811471, ..., -0.2141183 ,
#          0.53828596,  0.31572979],
#        [ 0.11765603,  0.1248059 , -0.86811471, ..., -0.27954888,
#          0.53828596, -0.40238261]])

# %% [markdown]
# <h1>做出来一个模型</h1>

# %%
model = RandomForestClassifier(class_weight="balanced")
model.fit(x, y)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
accuracy_score(y, model.predict(x))
# Out:
# 1.0

# %%
f1_score(y, model.predict(x))
# Out:
# 1.0

# %%
dump(model, "../models/RandomForest.pkl")
# Out:
# ['../models/RandomForest.pkl']

# %% [markdown]
# <h1>处理测试数据</h1>

# %% [markdown]
# <h2>数据预处理</h2>

# %% [markdown]
# <h3>档案数据预处理</h3>

# %%
cons_info_test = pd.read_csv("../data/测试组_比特币挖矿_档案明细（20211220）.csv", index_col=0, quotechar='"', encoding="gbk")
cons_info_test
# Out:
#            ELEC_TYPE_NAME VOLT_NAME      PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 179406029        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406030        城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 179406094        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406097        城镇居民生活用电    交流220V  居民生活<1kV(合表)           4.0      4.0
# 179406099        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# ...                   ...       ...           ...           ...      ...
# 2849971818       乡村居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2850017469       乡村居民生活用电    交流380V  居民生活<1kV(合表)         120.0    120.0
# 2850017472       乡村居民生活用电    交流380V  居民生活<1kV(合表)         720.0    720.0
# 2851323065       城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2852368013       城镇居民生活用电    交流380V  居民生活<1kV(合表)          52.5     52.5
#
#             SHIFT_NO           BUILD_DATE CANCEL_DATE  CHK_CYCLE  \
# ID
# 179406029        1.0            1998/12/1         NaN         24
# 179406030        NaN            1998/12/1         NaN         24
# 179406094        1.0             1999/4/1         NaN         24
# 179406097        1.0             1999/3/1         NaN         36
# 179406099        1.0            1998/12/1         NaN         24
# ...              ...                  ...         ...        ...
# 2849971818       NaN   2019/11/8 12:42:00         NaN        120
# 2850017469       NaN  2019/11/18 14:08:00         NaN        120
# 2850017472       NaN  2019/11/18 14:08:00         NaN        120
# 2851323065       NaN  2019/11/11 15:29:00         NaN        120
# 2852368013       NaN  2019/12/20 11:44:00         NaN        120
#
#                   LAST_CHK_DATE TMP_NAME  TMP_DATE
# ID
# 179406029             1998/12/1    非临时用电       NaN
# 179406030             1998/12/1    非临时用电       NaN
# 179406094              1999/4/1    非临时用电       NaN
# 179406097              1999/3/1    非临时用电       NaN
# 179406099             1998/12/1    非临时用电       NaN
# ...                         ...      ...       ...
# 2849971818   2019/11/8 12:42:00    非临时用电       NaN
# 2850017469  2019/11/18 14:08:00    非临时用电       NaN
# 2850017472  2019/11/18 14:08:00    非临时用电       NaN
# 2851323065  2019/11/11 15:29:00    非临时用电       NaN
# 2852368013  2019/12/20 11:44:00    非临时用电       NaN
#
# [15379 rows x 12 columns]

# %%
cons_info_test = cons_info_test.drop(columns=["CANCEL_DATE", "TMP_DATE"])
cons_info_test
# Out:
#            ELEC_TYPE_NAME VOLT_NAME      PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 179406029        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406030        城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 179406094        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406097        城镇居民生活用电    交流220V  居民生活<1kV(合表)           4.0      4.0
# 179406099        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# ...                   ...       ...           ...           ...      ...
# 2849971818       乡村居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2850017469       乡村居民生活用电    交流380V  居民生活<1kV(合表)         120.0    120.0
# 2850017472       乡村居民生活用电    交流380V  居民生活<1kV(合表)         720.0    720.0
# 2851323065       城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2852368013       城镇居民生活用电    交流380V  居民生活<1kV(合表)          52.5     52.5
#
#             SHIFT_NO           BUILD_DATE  CHK_CYCLE        LAST_CHK_DATE  \
# ID
# 179406029        1.0            1998/12/1         24            1998/12/1
# 179406030        NaN            1998/12/1         24            1998/12/1
# 179406094        1.0             1999/4/1         24             1999/4/1
# 179406097        1.0             1999/3/1         36             1999/3/1
# 179406099        1.0            1998/12/1         24            1998/12/1
# ...              ...                  ...        ...                  ...
# 2849971818       NaN   2019/11/8 12:42:00        120   2019/11/8 12:42:00
# 2850017469       NaN  2019/11/18 14:08:00        120  2019/11/18 14:08:00
# 2850017472       NaN  2019/11/18 14:08:00        120  2019/11/18 14:08:00
# 2851323065       NaN  2019/11/11 15:29:00        120  2019/11/11 15:29:00
# 2852368013       NaN  2019/12/20 11:44:00        120  2019/12/20 11:44:00
#
#            TMP_NAME
# ID
# 179406029     非临时用电
# 179406030     非临时用电
# 179406094     非临时用电
# 179406097     非临时用电
# 179406099     非临时用电
# ...             ...
# 2849971818    非临时用电
# 2850017469    非临时用电
# 2850017472    非临时用电
# 2851323065    非临时用电
# 2852368013    非临时用电
#
# [15379 rows x 10 columns]

# %%
cons_info_test["BUILD_DATE"] = pd.to_datetime(cons_info_test["BUILD_DATE"])
cons_info_test["LAST_CHK_DATE"] = pd.to_datetime(cons_info_test["LAST_CHK_DATE"])
cons_info_test
# Out:
#            ELEC_TYPE_NAME VOLT_NAME      PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 179406029        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406030        城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 179406094        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406097        城镇居民生活用电    交流220V  居民生活<1kV(合表)           4.0      4.0
# 179406099        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# ...                   ...       ...           ...           ...      ...
# 2849971818       乡村居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2850017469       乡村居民生活用电    交流380V  居民生活<1kV(合表)         120.0    120.0
# 2850017472       乡村居民生活用电    交流380V  居民生活<1kV(合表)         720.0    720.0
# 2851323065       城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2852368013       城镇居民生活用电    交流380V  居民生活<1kV(合表)          52.5     52.5
#
#             SHIFT_NO          BUILD_DATE  CHK_CYCLE       LAST_CHK_DATE  \
# ID
# 179406029        1.0 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# 179406030        NaN 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# 179406094        1.0 1999-04-01 00:00:00         24 1999-04-01 00:00:00
# 179406097        1.0 1999-03-01 00:00:00         36 1999-03-01 00:00:00
# 179406099        1.0 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# ...              ...                 ...        ...                 ...
# 2849971818       NaN 2019-11-08 12:42:00        120 2019-11-08 12:42:00
# 2850017469       NaN 2019-11-18 14:08:00        120 2019-11-18 14:08:00
# 2850017472       NaN 2019-11-18 14:08:00        120 2019-11-18 14:08:00
# 2851323065       NaN 2019-11-11 15:29:00        120 2019-11-11 15:29:00
# 2852368013       NaN 2019-12-20 11:44:00        120 2019-12-20 11:44:00
#
#            TMP_NAME
# ID
# 179406029     非临时用电
# 179406030     非临时用电
# 179406094     非临时用电
# 179406097     非临时用电
# 179406099     非临时用电
# ...             ...
# 2849971818    非临时用电
# 2850017469    非临时用电
# 2850017472    非临时用电
# 2851323065    非临时用电
# 2852368013    非临时用电
#
# [15379 rows x 10 columns]

# %%
cons_info_test["SHIFT_NO"] = cons_info_test["SHIFT_NO"].fillna(0)
cons_info_test
# Out:
#            ELEC_TYPE_NAME VOLT_NAME      PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 179406029        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406030        城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 179406094        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406097        城镇居民生活用电    交流220V  居民生活<1kV(合表)           4.0      4.0
# 179406099        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# ...                   ...       ...           ...           ...      ...
# 2849971818       乡村居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2850017469       乡村居民生活用电    交流380V  居民生活<1kV(合表)         120.0    120.0
# 2850017472       乡村居民生活用电    交流380V  居民生活<1kV(合表)         720.0    720.0
# 2851323065       城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2852368013       城镇居民生活用电    交流380V  居民生活<1kV(合表)          52.5     52.5
#
#             SHIFT_NO          BUILD_DATE  CHK_CYCLE       LAST_CHK_DATE  \
# ID
# 179406029        1.0 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# 179406030        0.0 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# 179406094        1.0 1999-04-01 00:00:00         24 1999-04-01 00:00:00
# 179406097        1.0 1999-03-01 00:00:00         36 1999-03-01 00:00:00
# 179406099        1.0 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# ...              ...                 ...        ...                 ...
# 2849971818       0.0 2019-11-08 12:42:00        120 2019-11-08 12:42:00
# 2850017469       0.0 2019-11-18 14:08:00        120 2019-11-18 14:08:00
# 2850017472       0.0 2019-11-18 14:08:00        120 2019-11-18 14:08:00
# 2851323065       0.0 2019-11-11 15:29:00        120 2019-11-11 15:29:00
# 2852368013       0.0 2019-12-20 11:44:00        120 2019-12-20 11:44:00
#
#            TMP_NAME
# ID
# 179406029     非临时用电
# 179406030     非临时用电
# 179406094     非临时用电
# 179406097     非临时用电
# 179406099     非临时用电
# ...             ...
# 2849971818    非临时用电
# 2850017469    非临时用电
# 2850017472    非临时用电
# 2851323065    非临时用电
# 2852368013    非临时用电
#
# [15379 rows x 10 columns]

# %%
cons_info_test["now"] = "2021-12-31"
cons_info_test["now"] = pd.to_datetime(cons_info_test["now"])
cons_info_test
# Out:
#            ELEC_TYPE_NAME VOLT_NAME      PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 179406029        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406030        城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 179406094        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406097        城镇居民生活用电    交流220V  居民生活<1kV(合表)           4.0      4.0
# 179406099        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# ...                   ...       ...           ...           ...      ...
# 2849971818       乡村居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2850017469       乡村居民生活用电    交流380V  居民生活<1kV(合表)         120.0    120.0
# 2850017472       乡村居民生活用电    交流380V  居民生活<1kV(合表)         720.0    720.0
# 2851323065       城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2852368013       城镇居民生活用电    交流380V  居民生活<1kV(合表)          52.5     52.5
#
#             SHIFT_NO          BUILD_DATE  CHK_CYCLE       LAST_CHK_DATE  \
# ID
# 179406029        1.0 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# 179406030        0.0 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# 179406094        1.0 1999-04-01 00:00:00         24 1999-04-01 00:00:00
# 179406097        1.0 1999-03-01 00:00:00         36 1999-03-01 00:00:00
# 179406099        1.0 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# ...              ...                 ...        ...                 ...
# 2849971818       0.0 2019-11-08 12:42:00        120 2019-11-08 12:42:00
# 2850017469       0.0 2019-11-18 14:08:00        120 2019-11-18 14:08:00
# 2850017472       0.0 2019-11-18 14:08:00        120 2019-11-18 14:08:00
# 2851323065       0.0 2019-11-11 15:29:00        120 2019-11-11 15:29:00
# 2852368013       0.0 2019-12-20 11:44:00        120 2019-12-20 11:44:00
#
#            TMP_NAME        now
# ID
# 179406029     非临时用电 2021-12-31
# 179406030     非临时用电 2021-12-31
# 179406094     非临时用电 2021-12-31
# 179406097     非临时用电 2021-12-31
# 179406099     非临时用电 2021-12-31
# ...             ...        ...
# 2849971818    非临时用电 2021-12-31
# 2850017469    非临时用电 2021-12-31
# 2850017472    非临时用电 2021-12-31
# 2851323065    非临时用电 2021-12-31
# 2852368013    非临时用电 2021-12-31
#
# [15379 rows x 11 columns]

# %%
cons_info_test["live_days"] = (cons_info_test["now"] - cons_info_test["BUILD_DATE"]).map(lambda x: x.days)
cons_info_test["check_days"] = (cons_info_test["now"] - cons_info_test["LAST_CHK_DATE"]).map(lambda x: x.days)
cons_info_test
# Out:
#            ELEC_TYPE_NAME VOLT_NAME      PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 179406029        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406030        城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 179406094        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406097        城镇居民生活用电    交流220V  居民生活<1kV(合表)           4.0      4.0
# 179406099        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# ...                   ...       ...           ...           ...      ...
# 2849971818       乡村居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2850017469       乡村居民生活用电    交流380V  居民生活<1kV(合表)         120.0    120.0
# 2850017472       乡村居民生活用电    交流380V  居民生活<1kV(合表)         720.0    720.0
# 2851323065       城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2852368013       城镇居民生活用电    交流380V  居民生活<1kV(合表)          52.5     52.5
#
#             SHIFT_NO          BUILD_DATE  CHK_CYCLE       LAST_CHK_DATE  \
# ID
# 179406029        1.0 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# 179406030        0.0 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# 179406094        1.0 1999-04-01 00:00:00         24 1999-04-01 00:00:00
# 179406097        1.0 1999-03-01 00:00:00         36 1999-03-01 00:00:00
# 179406099        1.0 1998-12-01 00:00:00         24 1998-12-01 00:00:00
# ...              ...                 ...        ...                 ...
# 2849971818       0.0 2019-11-08 12:42:00        120 2019-11-08 12:42:00
# 2850017469       0.0 2019-11-18 14:08:00        120 2019-11-18 14:08:00
# 2850017472       0.0 2019-11-18 14:08:00        120 2019-11-18 14:08:00
# 2851323065       0.0 2019-11-11 15:29:00        120 2019-11-11 15:29:00
# 2852368013       0.0 2019-12-20 11:44:00        120 2019-12-20 11:44:00
#
#            TMP_NAME        now  live_days  check_days
# ID
# 179406029     非临时用电 2021-12-31       8431        8431
# 179406030     非临时用电 2021-12-31       8431        8431
# 179406094     非临时用电 2021-12-31       8310        8310
# 179406097     非临时用电 2021-12-31       8341        8341
# 179406099     非临时用电 2021-12-31       8431        8431
# ...             ...        ...        ...         ...
# 2849971818    非临时用电 2021-12-31        783         783
# 2850017469    非临时用电 2021-12-31        773         773
# 2850017472    非临时用电 2021-12-31        773         773
# 2851323065    非临时用电 2021-12-31        780         780
# 2852368013    非临时用电 2021-12-31        741         741
#
# [15379 rows x 13 columns]

# %%
cons_info_test = cons_info_test.drop(columns=["BUILD_DATE", "LAST_CHK_DATE", "now"])
cons_info_test
# Out:
#            ELEC_TYPE_NAME VOLT_NAME      PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 179406029        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406030        城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 179406094        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# 179406097        城镇居民生活用电    交流220V  居民生活<1kV(合表)           4.0      4.0
# 179406099        城镇居民生活用电    交流220V  居民生活<1kV(合表)           2.0      2.0
# ...                   ...       ...           ...           ...      ...
# 2849971818       乡村居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2850017469       乡村居民生活用电    交流380V  居民生活<1kV(合表)         120.0    120.0
# 2850017472       乡村居民生活用电    交流380V  居民生活<1kV(合表)         720.0    720.0
# 2851323065       城镇居民生活用电    交流220V  居民生活<1kV(合表)          12.0     12.0
# 2852368013       城镇居民生活用电    交流380V  居民生活<1kV(合表)          52.5     52.5
#
#             SHIFT_NO  CHK_CYCLE TMP_NAME  live_days  check_days
# ID
# 179406029        1.0         24    非临时用电       8431        8431
# 179406030        0.0         24    非临时用电       8431        8431
# 179406094        1.0         24    非临时用电       8310        8310
# 179406097        1.0         36    非临时用电       8341        8341
# 179406099        1.0         24    非临时用电       8431        8431
# ...              ...        ...      ...        ...         ...
# 2849971818       0.0        120    非临时用电        783         783
# 2850017469       0.0        120    非临时用电        773         773
# 2850017472       0.0        120    非临时用电        773         773
# 2851323065       0.0        120    非临时用电        780         780
# 2852368013       0.0        120    非临时用电        741         741
#
# [15379 rows x 10 columns]

# %%
cons_info_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15379 entries, 179406029 to 2852368013
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ELEC_TYPE_NAME  15379 non-null  object
#  1   VOLT_NAME       15379 non-null  object
#  2   PRC_NAME        15379 non-null  object
#  3   CONTRACT_CAP    15379 non-null  float64
#  4   RUN_CAP         15379 non-null  float64
#  5   SHIFT_NO        15379 non-null  float64
#  6   CHK_CYCLE       15379 non-null  int64
#  7   TMP_NAME        15379 non-null  object
#  8   live_days       15379 non-null  int64
#  9   check_days      15379 non-null  int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 1.3+ MB

# %%
cons_info_test = pd.get_dummies(cons_info_test)
cons_info_test
# Out:
#             CONTRACT_CAP  RUN_CAP  SHIFT_NO  CHK_CYCLE  live_days  check_days  \
# ID
# 179406029            2.0      2.0       1.0         24       8431        8431
# 179406030           12.0     12.0       0.0         24       8431        8431
# 179406094            2.0      2.0       1.0         24       8310        8310
# 179406097            4.0      4.0       1.0         36       8341        8341
# 179406099            2.0      2.0       1.0         24       8431        8431
# ...                  ...      ...       ...        ...        ...         ...
# 2849971818          12.0     12.0       0.0        120        783         783
# 2850017469         120.0    120.0       0.0        120        773         773
# 2850017472         720.0    720.0       0.0        120        773         773
# 2851323065          12.0     12.0       0.0        120        780         780
# 2852368013          52.5     52.5       0.0        120        741         741
#
#             ELEC_TYPE_NAME_乡村居民生活用电  ELEC_TYPE_NAME_农业生产用电  \
# ID
# 179406029                         0                      0
# 179406030                         0                      0
# 179406094                         0                      0
# 179406097                         0                      0
# 179406099                         0                      0
# ...                             ...                    ...
# 2849971818                        1                      0
# 2850017469                        1                      0
# 2850017472                        1                      0
# 2851323065                        0                      0
# 2852368013                        0                      0
#
#             ELEC_TYPE_NAME_商业用电  ELEC_TYPE_NAME_城镇居民生活用电  ...  \
# ID                                                        ...
# 179406029                     0                        1  ...
# 179406030                     0                        1  ...
# 179406094                     0                        1  ...
# 179406097                     0                        1  ...
# 179406099                     0                        1  ...
# ...                         ...                      ...  ...
# 2849971818                    0                        0  ...
# 2850017469                    0                        0  ...
# 2850017472                    0                        0  ...
# 2851323065                    0                        1  ...
# 2852368013                    0                        1  ...
#
#             ELEC_TYPE_NAME_非居民照明  ELEC_TYPE_NAME_非工业  VOLT_NAME_交流10kV  \
# ID
# 179406029                      0                   0                 0
# 179406030                      0                   0                 0
# 179406094                      0                   0                 0
# 179406097                      0                   0                 0
# 179406099                      0                   0                 0
# ...                          ...                 ...               ...
# 2849971818                     0                   0                 0
# 2850017469                     0                   0                 0
# 2850017472                     0                   0                 0
# 2851323065                     0                   0                 0
# 2852368013                     0                   0                 0
#
#             VOLT_NAME_交流220V  VOLT_NAME_交流380V  VOLT_NAME_交流6kV  \
# ID
# 179406029                  1                 0                0
# 179406030                  1                 0                0
# 179406094                  1                 0                0
# 179406097                  1                 0                0
# 179406099                  1                 0                0
# ...                      ...               ...              ...
# 2849971818                 1                 0                0
# 2850017469                 0                 1                0
# 2850017472                 0                 1                0
# 2851323065                 1                 0                0
# 2852368013                 0                 1                0
#
#             PRC_NAME_居民合表电价(1-10千伏）  PRC_NAME_居民生活1_10kV(合表)  \
# ID
# 179406029                         0                        0
# 179406030                         0                        0
# 179406094                         0                        0
# 179406097                         0                        0
# 179406099                         0                        0
# ...                             ...                      ...
# 2849971818                        0                        0
# 2850017469                        0                        0
# 2850017472                        0                        0
# 2851323065                        0                        0
# 2852368013                        0                        0
#
#             PRC_NAME_居民生活<1kV(合表)  TMP_NAME_非临时用电
# ID
# 179406029                       1               1
# 179406030                       1               1
# 179406094                       1               1
# 179406097                       1               1
# 179406099                       1               1
# ...                           ...             ...
# 2849971818                      1               1
# 2850017469                      1               1
# 2850017472                      1               1
# 2851323065                      1               1
# 2852368013                      1               1
#
# [15379 rows x 24 columns]

# %%
cons_info_test["CHK_CYCLE"] = cons_info_test["CHK_CYCLE"].fillna(cons_info_test["CHK_CYCLE"].median())
cons_info_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15379 entries, 179406029 to 2852368013
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CONTRACT_CAP                15379 non-null  float64
#  1   RUN_CAP                     15379 non-null  float64
#  2   SHIFT_NO                    15379 non-null  float64
#  3   CHK_CYCLE                   15379 non-null  int64
#  4   live_days                   15379 non-null  int64
#  5   check_days                  15379 non-null  int64
#  6   ELEC_TYPE_NAME_乡村居民生活用电     15379 non-null  uint8
#  7   ELEC_TYPE_NAME_农业生产用电       15379 non-null  uint8
#  8   ELEC_TYPE_NAME_商业用电         15379 non-null  uint8
#  9   ELEC_TYPE_NAME_城镇居民生活用电     15379 non-null  uint8
#  10  ELEC_TYPE_NAME_大工业用电        15379 non-null  uint8
#  11  ELEC_TYPE_NAME_学校教学和学生生活用电  15379 non-null  uint8
#  12  ELEC_TYPE_NAME_居民生活用电       15379 non-null  uint8
#  13  ELEC_TYPE_NAME_普通工业         15379 non-null  uint8
#  14  ELEC_TYPE_NAME_非居民照明        15379 non-null  uint8
#  15  ELEC_TYPE_NAME_非工业          15379 non-null  uint8
#  16  VOLT_NAME_交流10kV            15379 non-null  uint8
#  17  VOLT_NAME_交流220V            15379 non-null  uint8
#  18  VOLT_NAME_交流380V            15379 non-null  uint8
#  19  VOLT_NAME_交流6kV             15379 non-null  uint8
#  20  PRC_NAME_居民合表电价(1-10千伏）     15379 non-null  uint8
#  21  PRC_NAME_居民生活1_10kV(合表)     15379 non-null  uint8
#  22  PRC_NAME_居民生活<1kV(合表)       15379 non-null  uint8
#  23  TMP_NAME_非临时用电              15379 non-null  uint8
# dtypes: float64(3), int64(3), uint8(18)
# memory usage: 1.1 MB

# %%
cons_info_test["PRC_NAME_居民合表电价(1-10千伏）"] = cons_info_test["PRC_NAME_居民合表电价(1-10千伏）"] + cons_info_test["PRC_NAME_居民生活1_10kV(合表)"]
cons_info_test = cons_info_test.drop(columns=["PRC_NAME_居民生活1_10kV(合表)"])
cons_info_test
# Out:
#             CONTRACT_CAP  RUN_CAP  SHIFT_NO  CHK_CYCLE  live_days  check_days  \
# ID
# 179406029            2.0      2.0       1.0         24       8431        8431
# 179406030           12.0     12.0       0.0         24       8431        8431
# 179406094            2.0      2.0       1.0         24       8310        8310
# 179406097            4.0      4.0       1.0         36       8341        8341
# 179406099            2.0      2.0       1.0         24       8431        8431
# ...                  ...      ...       ...        ...        ...         ...
# 2849971818          12.0     12.0       0.0        120        783         783
# 2850017469         120.0    120.0       0.0        120        773         773
# 2850017472         720.0    720.0       0.0        120        773         773
# 2851323065          12.0     12.0       0.0        120        780         780
# 2852368013          52.5     52.5       0.0        120        741         741
#
#             ELEC_TYPE_NAME_乡村居民生活用电  ELEC_TYPE_NAME_农业生产用电  \
# ID
# 179406029                         0                      0
# 179406030                         0                      0
# 179406094                         0                      0
# 179406097                         0                      0
# 179406099                         0                      0
# ...                             ...                    ...
# 2849971818                        1                      0
# 2850017469                        1                      0
# 2850017472                        1                      0
# 2851323065                        0                      0
# 2852368013                        0                      0
#
#             ELEC_TYPE_NAME_商业用电  ELEC_TYPE_NAME_城镇居民生活用电  ...  \
# ID                                                        ...
# 179406029                     0                        1  ...
# 179406030                     0                        1  ...
# 179406094                     0                        1  ...
# 179406097                     0                        1  ...
# 179406099                     0                        1  ...
# ...                         ...                      ...  ...
# 2849971818                    0                        0  ...
# 2850017469                    0                        0  ...
# 2850017472                    0                        0  ...
# 2851323065                    0                        1  ...
# 2852368013                    0                        1  ...
#
#             ELEC_TYPE_NAME_普通工业  ELEC_TYPE_NAME_非居民照明  ELEC_TYPE_NAME_非工业  \
# ID
# 179406029                     0                     0                   0
# 179406030                     0                     0                   0
# 179406094                     0                     0                   0
# 179406097                     0                     0                   0
# 179406099                     0                     0                   0
# ...                         ...                   ...                 ...
# 2849971818                    0                     0                   0
# 2850017469                    0                     0                   0
# 2850017472                    0                     0                   0
# 2851323065                    0                     0                   0
# 2852368013                    0                     0                   0
#
#             VOLT_NAME_交流10kV  VOLT_NAME_交流220V  VOLT_NAME_交流380V  \
# ID
# 179406029                  0                 1                 0
# 179406030                  0                 1                 0
# 179406094                  0                 1                 0
# 179406097                  0                 1                 0
# 179406099                  0                 1                 0
# ...                      ...               ...               ...
# 2849971818                 0                 1                 0
# 2850017469                 0                 0                 1
# 2850017472                 0                 0                 1
# 2851323065                 0                 1                 0
# 2852368013                 0                 0                 1
#
#             VOLT_NAME_交流6kV  PRC_NAME_居民合表电价(1-10千伏）  PRC_NAME_居民生活<1kV(合表)  \
# ID
# 179406029                 0                        0                      1
# 179406030                 0                        0                      1
# 179406094                 0                        0                      1
# 179406097                 0                        0                      1
# 179406099                 0                        0                      1
# ...                     ...                      ...                    ...
# 2849971818                0                        0                      1
# 2850017469                0                        0                      1
# 2850017472                0                        0                      1
# 2851323065                0                        0                      1
# 2852368013                0                        0                      1
#
#             TMP_NAME_非临时用电
# ID
# 179406029                1
# 179406030                1
# 179406094                1
# 179406097                1
# 179406099                1
# ...                    ...
# 2849971818               1
# 2850017469               1
# 2850017472               1
# 2851323065               1
# 2852368013               1
#
# [15379 rows x 23 columns]

# %%
cons_info_test = cons_info_test.rename(columns={"PRC_NAME_居民生活<1kV(合表)": "PRC_NAME_居民合表电价(不满1千伏）"})
cons_info_test
# Out:
#             CONTRACT_CAP  RUN_CAP  SHIFT_NO  CHK_CYCLE  live_days  check_days  \
# ID
# 179406029            2.0      2.0       1.0         24       8431        8431
# 179406030           12.0     12.0       0.0         24       8431        8431
# 179406094            2.0      2.0       1.0         24       8310        8310
# 179406097            4.0      4.0       1.0         36       8341        8341
# 179406099            2.0      2.0       1.0         24       8431        8431
# ...                  ...      ...       ...        ...        ...         ...
# 2849971818          12.0     12.0       0.0        120        783         783
# 2850017469         120.0    120.0       0.0        120        773         773
# 2850017472         720.0    720.0       0.0        120        773         773
# 2851323065          12.0     12.0       0.0        120        780         780
# 2852368013          52.5     52.5       0.0        120        741         741
#
#             ELEC_TYPE_NAME_乡村居民生活用电  ELEC_TYPE_NAME_农业生产用电  \
# ID
# 179406029                         0                      0
# 179406030                         0                      0
# 179406094                         0                      0
# 179406097                         0                      0
# 179406099                         0                      0
# ...                             ...                    ...
# 2849971818                        1                      0
# 2850017469                        1                      0
# 2850017472                        1                      0
# 2851323065                        0                      0
# 2852368013                        0                      0
#
#             ELEC_TYPE_NAME_商业用电  ELEC_TYPE_NAME_城镇居民生活用电  ...  \
# ID                                                        ...
# 179406029                     0                        1  ...
# 179406030                     0                        1  ...
# 179406094                     0                        1  ...
# 179406097                     0                        1  ...
# 179406099                     0                        1  ...
# ...                         ...                      ...  ...
# 2849971818                    0                        0  ...
# 2850017469                    0                        0  ...
# 2850017472                    0                        0  ...
# 2851323065                    0                        1  ...
# 2852368013                    0                        1  ...
#
#             ELEC_TYPE_NAME_普通工业  ELEC_TYPE_NAME_非居民照明  ELEC_TYPE_NAME_非工业  \
# ID
# 179406029                     0                     0                   0
# 179406030                     0                     0                   0
# 179406094                     0                     0                   0
# 179406097                     0                     0                   0
# 179406099                     0                     0                   0
# ...                         ...                   ...                 ...
# 2849971818                    0                     0                   0
# 2850017469                    0                     0                   0
# 2850017472                    0                     0                   0
# 2851323065                    0                     0                   0
# 2852368013                    0                     0                   0
#
#             VOLT_NAME_交流10kV  VOLT_NAME_交流220V  VOLT_NAME_交流380V  \
# ID
# 179406029                  0                 1                 0
# 179406030                  0                 1                 0
# 179406094                  0                 1                 0
# 179406097                  0                 1                 0
# 179406099                  0                 1                 0
# ...                      ...               ...               ...
# 2849971818                 0                 1                 0
# 2850017469                 0                 0                 1
# 2850017472                 0                 0                 1
# 2851323065                 0                 1                 0
# 2852368013                 0                 0                 1
#
#             VOLT_NAME_交流6kV  PRC_NAME_居民合表电价(1-10千伏）  PRC_NAME_居民合表电价(不满1千伏）  \
# ID
# 179406029                 0                        0                       1
# 179406030                 0                        0                       1
# 179406094                 0                        0                       1
# 179406097                 0                        0                       1
# 179406099                 0                        0                       1
# ...                     ...                      ...                     ...
# 2849971818                0                        0                       1
# 2850017469                0                        0                       1
# 2850017472                0                        0                       1
# 2851323065                0                        0                       1
# 2852368013                0                        0                       1
#
#             TMP_NAME_非临时用电
# ID
# 179406029                1
# 179406030                1
# 179406094                1
# 179406097                1
# 179406099                1
# ...                    ...
# 2849971818               1
# 2850017469               1
# 2850017472               1
# 2851323065               1
# 2852368013               1
#
# [15379 rows x 23 columns]

# %%
cons_info_test["VOLT_NAME_交流10kV"] = cons_info_test["VOLT_NAME_交流10kV"] + cons_info_test["VOLT_NAME_交流6kV"]
cons_info_test = cons_info_test.drop(columns=["VOLT_NAME_交流6kV"])
cons_info_test
# Out:
#             CONTRACT_CAP  RUN_CAP  SHIFT_NO  CHK_CYCLE  live_days  check_days  \
# ID
# 179406029            2.0      2.0       1.0         24       8431        8431
# 179406030           12.0     12.0       0.0         24       8431        8431
# 179406094            2.0      2.0       1.0         24       8310        8310
# 179406097            4.0      4.0       1.0         36       8341        8341
# 179406099            2.0      2.0       1.0         24       8431        8431
# ...                  ...      ...       ...        ...        ...         ...
# 2849971818          12.0     12.0       0.0        120        783         783
# 2850017469         120.0    120.0       0.0        120        773         773
# 2850017472         720.0    720.0       0.0        120        773         773
# 2851323065          12.0     12.0       0.0        120        780         780
# 2852368013          52.5     52.5       0.0        120        741         741
#
#             ELEC_TYPE_NAME_乡村居民生活用电  ELEC_TYPE_NAME_农业生产用电  \
# ID
# 179406029                         0                      0
# 179406030                         0                      0
# 179406094                         0                      0
# 179406097                         0                      0
# 179406099                         0                      0
# ...                             ...                    ...
# 2849971818                        1                      0
# 2850017469                        1                      0
# 2850017472                        1                      0
# 2851323065                        0                      0
# 2852368013                        0                      0
#
#             ELEC_TYPE_NAME_商业用电  ELEC_TYPE_NAME_城镇居民生活用电  ...  \
# ID                                                        ...
# 179406029                     0                        1  ...
# 179406030                     0                        1  ...
# 179406094                     0                        1  ...
# 179406097                     0                        1  ...
# 179406099                     0                        1  ...
# ...                         ...                      ...  ...
# 2849971818                    0                        0  ...
# 2850017469                    0                        0  ...
# 2850017472                    0                        0  ...
# 2851323065                    0                        1  ...
# 2852368013                    0                        1  ...
#
#             ELEC_TYPE_NAME_居民生活用电  ELEC_TYPE_NAME_普通工业  ELEC_TYPE_NAME_非居民照明  \
# ID
# 179406029                       0                    0                     0
# 179406030                       0                    0                     0
# 179406094                       0                    0                     0
# 179406097                       0                    0                     0
# 179406099                       0                    0                     0
# ...                           ...                  ...                   ...
# 2849971818                      0                    0                     0
# 2850017469                      0                    0                     0
# 2850017472                      0                    0                     0
# 2851323065                      0                    0                     0
# 2852368013                      0                    0                     0
#
#             ELEC_TYPE_NAME_非工业  VOLT_NAME_交流10kV  VOLT_NAME_交流220V  \
# ID
# 179406029                    0                 0                 1
# 179406030                    0                 0                 1
# 179406094                    0                 0                 1
# 179406097                    0                 0                 1
# 179406099                    0                 0                 1
# ...                        ...               ...               ...
# 2849971818                   0                 0                 1
# 2850017469                   0                 0                 0
# 2850017472                   0                 0                 0
# 2851323065                   0                 0                 1
# 2852368013                   0                 0                 0
#
#             VOLT_NAME_交流380V  PRC_NAME_居民合表电价(1-10千伏）  PRC_NAME_居民合表电价(不满1千伏）  \
# ID
# 179406029                  0                        0                       1
# 179406030                  0                        0                       1
# 179406094                  0                        0                       1
# 179406097                  0                        0                       1
# 179406099                  0                        0                       1
# ...                      ...                      ...                     ...
# 2849971818                 0                        0                       1
# 2850017469                 1                        0                       1
# 2850017472                 1                        0                       1
# 2851323065                 0                        0                       1
# 2852368013                 1                        0                       1
#
#             TMP_NAME_非临时用电
# ID
# 179406029                1
# 179406030                1
# 179406094                1
# 179406097                1
# 179406099                1
# ...                    ...
# 2849971818               1
# 2850017469               1
# 2850017472               1
# 2851323065               1
# 2852368013               1
#
# [15379 rows x 22 columns]

# %%
cons_info_test["ELEC_TYPE_NAME_普通工业"] = cons_info_test["ELEC_TYPE_NAME_普通工业"] + cons_info_test["ELEC_TYPE_NAME_大工业用电"]
cons_info_test = cons_info_test.drop(columns=["ELEC_TYPE_NAME_大工业用电"])
cons_info_test["ELEC_TYPE_NAME_非工业"] = cons_info_test["ELEC_TYPE_NAME_非工业"] + cons_info_test["ELEC_TYPE_NAME_农业生产用电"]
cons_info_test = cons_info_test.drop(columns=["ELEC_TYPE_NAME_农业生产用电"])
cons_info_test
# Out:
#             CONTRACT_CAP  RUN_CAP  SHIFT_NO  CHK_CYCLE  live_days  check_days  \
# ID
# 179406029            2.0      2.0       1.0         24       8431        8431
# 179406030           12.0     12.0       0.0         24       8431        8431
# 179406094            2.0      2.0       1.0         24       8310        8310
# 179406097            4.0      4.0       1.0         36       8341        8341
# 179406099            2.0      2.0       1.0         24       8431        8431
# ...                  ...      ...       ...        ...        ...         ...
# 2849971818          12.0     12.0       0.0        120        783         783
# 2850017469         120.0    120.0       0.0        120        773         773
# 2850017472         720.0    720.0       0.0        120        773         773
# 2851323065          12.0     12.0       0.0        120        780         780
# 2852368013          52.5     52.5       0.0        120        741         741
#
#             ELEC_TYPE_NAME_乡村居民生活用电  ELEC_TYPE_NAME_商业用电  \
# ID
# 179406029                         0                    0
# 179406030                         0                    0
# 179406094                         0                    0
# 179406097                         0                    0
# 179406099                         0                    0
# ...                             ...                  ...
# 2849971818                        1                    0
# 2850017469                        1                    0
# 2850017472                        1                    0
# 2851323065                        0                    0
# 2852368013                        0                    0
#
#             ELEC_TYPE_NAME_城镇居民生活用电  ELEC_TYPE_NAME_学校教学和学生生活用电  \
# ID
# 179406029                         1                           0
# 179406030                         1                           0
# 179406094                         1                           0
# 179406097                         1                           0
# 179406099                         1                           0
# ...                             ...                         ...
# 2849971818                        0                           0
# 2850017469                        0                           0
# 2850017472                        0                           0
# 2851323065                        1                           0
# 2852368013                        1                           0
#
#             ELEC_TYPE_NAME_居民生活用电  ELEC_TYPE_NAME_普通工业  ELEC_TYPE_NAME_非居民照明  \
# ID
# 179406029                       0                    0                     0
# 179406030                       0                    0                     0
# 179406094                       0                    0                     0
# 179406097                       0                    0                     0
# 179406099                       0                    0                     0
# ...                           ...                  ...                   ...
# 2849971818                      0                    0                     0
# 2850017469                      0                    0                     0
# 2850017472                      0                    0                     0
# 2851323065                      0                    0                     0
# 2852368013                      0                    0                     0
#
#             ELEC_TYPE_NAME_非工业  VOLT_NAME_交流10kV  VOLT_NAME_交流220V  \
# ID
# 179406029                    0                 0                 1
# 179406030                    0                 0                 1
# 179406094                    0                 0                 1
# 179406097                    0                 0                 1
# 179406099                    0                 0                 1
# ...                        ...               ...               ...
# 2849971818                   0                 0                 1
# 2850017469                   0                 0                 0
# 2850017472                   0                 0                 0
# 2851323065                   0                 0                 1
# 2852368013                   0                 0                 0
#
#             VOLT_NAME_交流380V  PRC_NAME_居民合表电价(1-10千伏）  PRC_NAME_居民合表电价(不满1千伏）  \
# ID
# 179406029                  0                        0                       1
# 179406030                  0                        0                       1
# 179406094                  0                        0                       1
# 179406097                  0                        0                       1
# 179406099                  0                        0                       1
# ...                      ...                      ...                     ...
# 2849971818                 0                        0                       1
# 2850017469                 1                        0                       1
# 2850017472                 1                        0                       1
# 2851323065                 0                        0                       1
# 2852368013                 1                        0                       1
#
#             TMP_NAME_非临时用电
# ID
# 179406029                1
# 179406030                1
# 179406094                1
# 179406097                1
# 179406099                1
# ...                    ...
# 2849971818               1
# 2850017469               1
# 2850017472               1
# 2851323065               1
# 2852368013               1
#
# [15379 rows x 20 columns]

# %% [markdown]
# <h3>月电量处理</h3>

# %%
cons_info_test["pq_z_mean"] = 0
cons_info_test["pq_z_median"] = 0
cons_info_test["pq_z_std"] = 0
cons_info_test["pq_z_std/mean"] = 0
cons_info_test["pq_z_entropy"] = 0
cons_info_test["pq_fg_distance"] = 0
cons_info_test["pq_gp_diatance"] = 0
cons_info_test["pq_fp_distance"] = 0
cons_info_test["pq_fg_cosine"] = 0
cons_info_test["pq_gp_cosine"] = 0
cons_info_test["pq_fp_cosine"] = 0
cons_info_test["pq_fz_cosine"] = 0
cons_info_test["pq_gz_cosine"] = 0
cons_info_test["pq_pz_cosine"] = 0

# %%
elec_month_test = pd.read_csv("../data/测试组_比特币挖矿_月用电明细（20211217）.csv")
elec_month_test
# Out:
#                 id      ym  pq_f  pq_g  pq_p  pq_z
# 0        179438260  202001   244   111     1   356
# 1        179438260  202002   217   108    -1   324
# 2        179438260  202003   280    90     0   370
# 3        179438260  202004   338   118     1   457
# 4        179438260  202005   297   120    -1   416
# ...            ...     ...   ...   ...   ...   ...
# 338333  2880712108  202106   474   675     0  1149
# 338334  2880712108  202107   342   881     0  1223
# 338335  2880712108  202108   293   772     0  1065
# 338336  2880712108  202109   418   570    -1   987
# 338337  2880712108  202110   549   535     1  1085
#
# [338338 rows x 6 columns]

# %%
elec_month_test["ym"] = elec_month_test["ym"].astype(str)
elec_month_test
# Out:
#                 id      ym  pq_f  pq_g  pq_p  pq_z
# 0        179438260  202001   244   111     1   356
# 1        179438260  202002   217   108    -1   324
# 2        179438260  202003   280    90     0   370
# 3        179438260  202004   338   118     1   457
# 4        179438260  202005   297   120    -1   416
# ...            ...     ...   ...   ...   ...   ...
# 338333  2880712108  202106   474   675     0  1149
# 338334  2880712108  202107   342   881     0  1223
# 338335  2880712108  202108   293   772     0  1065
# 338336  2880712108  202109   418   570    -1   987
# 338337  2880712108  202110   549   535     1  1085
#
# [338338 rows x 6 columns]

# %%
for cons_id in tqdm(cons_info_test.index):
    df = elec_month_test[elec_month_test["id"] == cons_id]
    df = df.drop(columns=["id"]).sort_values("ym").set_index("ym")
    df = df.fillna(method="ffill").fillna(method="bfill")
    cons_info_test.loc[cons_id, "pq_z_mean"] = df["pq_z"].mean()
    cons_info_test.loc[cons_id, "pq_z_median"] = df["pq_z"].median()
    cons_info_test.loc[cons_id, "pq_z_std"] = df["pq_z"].std()
    cons_info_test.loc[(cons_info_test.index == cons_id) & (cons_info_test["pq_z_mean"] > 0), "pq_z_std/mean"] = cons_info_test["pq_z_std"] / cons_info_test["pq_z_mean"]
    cons_info_test.loc[cons_id, "pq_z_entropy"] = entropy(df["pq_z"])
    cons_info_test.loc[cons_id, "pq_fg_distance"] = distance.euclidean(df["pq_f"], df["pq_g"])
    cons_info_test.loc[cons_id, "pq_gp_diatance"] = distance.euclidean(df["pq_g"], df["pq_p"])
    cons_info_test.loc[cons_id, "pq_fp_distance"] = distance.euclidean(df["pq_f"], df["pq_p"])
    cons_info_test.loc[cons_id, "pq_fg_cosine"] = cosine(df["pq_f"], df["pq_g"])
    cons_info_test.loc[cons_id, "pq_gp_cosine"] = cosine(df["pq_g"], df["pq_p"])
    cons_info_test.loc[cons_id, "pq_fp_cosine"] = cosine(df["pq_f"], df["pq_p"])
    cons_info_test.loc[cons_id, "pq_fz_cosine"] = cosine(df["pq_f"], df["pq_z"])
    cons_info_test.loc[cons_id, "pq_gz_cosine"] = cosine(df["pq_g"], df["pq_z"])
    cons_info_test.loc[cons_id, "pq_pz_cosine"] = cosine(df["pq_p"], df["pq_z"])
    
cons_info_test
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 15379/15379 [01:37<00:00, 158.28it/s]
#             CONTRACT_CAP  RUN_CAP  SHIFT_NO  CHK_CYCLE  live_days  check_days  \
# ID
# 179406029            2.0      2.0       1.0         24       8431        8431
# 179406030           12.0     12.0       0.0         24       8431        8431
# 179406094            2.0      2.0       1.0         24       8310        8310
# 179406097            4.0      4.0       1.0         36       8341        8341
# 179406099            2.0      2.0       1.0         24       8431        8431
# ...                  ...      ...       ...        ...        ...         ...
# 2849971818          12.0     12.0       0.0        120        783         783
# 2850017469         120.0    120.0       0.0        120        773         773
# 2850017472         720.0    720.0       0.0        120        773         773
# 2851323065          12.0     12.0       0.0        120        780         780
# 2852368013          52.5     52.5       0.0        120        741         741
#
#             ELEC_TYPE_NAME_乡村居民生活用电  ELEC_TYPE_NAME_商业用电  \
# ID
# 179406029                         0                    0
# 179406030                         0                    0
# 179406094                         0                    0
# 179406097                         0                    0
# 179406099                         0                    0
# ...                             ...                  ...
# 2849971818                        1                    0
# 2850017469                        1                    0
# 2850017472                        1                    0
# 2851323065                        0                    0
# 2852368013                        0                    0
#
#             ELEC_TYPE_NAME_城镇居民生活用电  ELEC_TYPE_NAME_学校教学和学生生活用电  ...  \
# ID                                                               ...
# 179406029                         1                           0  ...
# 179406030                         1                           0  ...
# 179406094                         1                           0  ...
# 179406097                         1                           0  ...
# 179406099                         1                           0  ...
# ...                             ...                         ...  ...
# 2849971818                        0                           0  ...
# 2850017469                        0                           0  ...
# 2850017472                        0                           0  ...
# 2851323065                        1                           0  ...
# 2852368013                        1                           0  ...
#
#             pq_z_entropy  pq_fg_distance  pq_gp_diatance  pq_fp_distance  \
# ID
# 179406029       1.726709     1060.485738     1651.868639     2373.503318
# 179406030       1.807805        0.000000     1860.847388     1860.847388
# 179406094       1.444356     2299.037190      273.075081     2552.960243
# 179406097       1.960762      938.046374     1287.374460     2116.962919
# 179406099       1.960762      601.724189      739.004060     1311.739685
# ...                  ...             ...             ...             ...
# 2849971818      1.526775      742.787318      922.428317      234.194364
# 2850017469      0.000000        0.000000        0.000000        0.000000
# 2850017472      1.873965    18585.460554    15366.992809     4487.578857
# 2851323065      1.943998      927.960128      242.895039     1162.125639
# 2852368013      1.591020     1439.979167     1500.595882      164.839316
#
#             pq_fg_cosine  pq_gp_cosine  pq_fp_cosine  pq_fz_cosine  \
# ID
# 179406029       0.076989      0.979375      0.957193      0.013026
# 179406030       0.000000      1.000000      1.000000      1.000000
# 179406094       0.062809      1.114785      1.105565      0.000572
# 179406097       0.035125      1.198773      1.104793      0.005005
# 179406099       0.017548      1.080833      1.068587      0.002274
# ...                  ...           ...           ...           ...
# 2849971818      0.179678      0.845413      0.918948      0.117407
# 2850017469      0.000000      0.000000      0.000000      0.000000
# 2850017472      0.007583      0.009663      0.002064      0.000712
# 2851323065      0.028253      0.787298      0.764655      0.000838
# 2852368013      0.005184      0.004132      0.000354      0.000568
#
#             pq_gz_cosine  pq_pz_cosine
# ID
# 179406029       0.027111      0.964811
# 179406030       1.000000      0.000000
# 179406094       0.051562      1.105591
# 179406097       0.013703      1.140851
# 179406099       0.007213      1.072008
# ...                  ...           ...
# 2849971818      0.007121      0.853454
# 2850017469      0.000000      0.000000
# 2850017472      0.004659      0.001275
# 2851323065      0.019418      0.765847
# 2852368013      0.002430      0.000281
#
# [15379 rows x 34 columns]

# %% [markdown]
# <h3>日电量处理</h3>

# %%
cons_info_test["kwh_mean"] = 0
cons_info_test["kwh_median"] = 0
cons_info_test["kwh_std"] = 0
cons_info_test["kwh_std/mean"] = 0
cons_info_test["kwh_entropy"] = 0
cons_info_test["kwh_pap_r12_distance"] = 0
cons_info_test["kwh_pap_r13_distance"] = 0
cons_info_test["kwh_pap_r14_distance"] = 0
cons_info_test["kwh_pap_r23_distance"] = 0
cons_info_test["kwh_pap_r24_distance"] = 0
cons_info_test["kwh_pap_r34_distance"] = 0
cons_info_test["kwh_pap_r12_cosine"] = 0
cons_info_test["kwh_pap_r13_cosine"] = 0
cons_info_test["kwh_pap_r14_cosine"] = 0
cons_info_test["kwh_pap_r23_cosine"] = 0
cons_info_test["kwh_pap_r24_cosine"] = 0
cons_info_test["kwh_pap_r34_cosine"] = 0
cons_info_test["kwh_pap_r1_cosine"] = 0
cons_info_test["kwh_pap_r2_cosine"] = 0
cons_info_test["kwh_pap_r3_cosine"] = 0
cons_info_test["kwh_pap_r4_cosine"] = 0

# %%
elec_day_test = pd.read_csv("../data/测试组_比特币挖矿_日用电明细（20211217）.csv")
elec_day_test
# Out:
#                  id                   rq    kwh  kwh_rap  kwh_pap_r1  \
# 0         179404030  2020-01-22 00:00:00  51.77      NaN         0.0
# 1         179404030  2020-01-23 00:00:00  73.27      NaN         0.0
# 2         179404030  2020-01-24 00:00:00  74.90      NaN         0.0
# 3         179404030  2020-01-25 00:00:00  62.73      NaN         0.0
# 4         179404030  2020-01-26 00:00:00  64.27      NaN         0.0
# ...             ...                  ...    ...      ...         ...
# 1660582  2880712108  2021-10-05 00:00:00  44.85      NaN         0.0
# 1660583  2880712108  2021-10-06 00:00:00  28.89      NaN         0.0
# 1660584  2880712108  2021-10-07 00:00:00  51.10      NaN         0.0
# 1660585  2880712108  2021-10-08 00:00:00  17.96      NaN         0.0
# 1660586  2880712108  2021-10-09 00:00:00  76.19      NaN         0.0
#
#          kwh_pap_r2  kwh_pap_r3  kwh_pap_r4
# 0             33.47         0.0       18.31
# 1             51.83         0.0       21.44
# 2             52.20         0.0       22.70
# 3             37.27         0.0       25.45
# 4             41.72         0.0       22.56
# ...             ...         ...         ...
# 1660582       22.14         0.0       22.71
# 1660583       14.94         0.0       13.95
# 1660584       27.27         0.0       23.84
# 1660585        7.19         0.0       10.76
# 1660586       24.67         0.0       51.53
#
# [1660587 rows x 8 columns]

# %%
elec_day_test["rq"] = pd.to_datetime(elec_day_test["rq"])
elec_day_test
# Out:
#                  id         rq    kwh  kwh_rap  kwh_pap_r1  kwh_pap_r2  \
# 0         179404030 2020-01-22  51.77      NaN         0.0       33.47
# 1         179404030 2020-01-23  73.27      NaN         0.0       51.83
# 2         179404030 2020-01-24  74.90      NaN         0.0       52.20
# 3         179404030 2020-01-25  62.73      NaN         0.0       37.27
# 4         179404030 2020-01-26  64.27      NaN         0.0       41.72
# ...             ...        ...    ...      ...         ...         ...
# 1660582  2880712108 2021-10-05  44.85      NaN         0.0       22.14
# 1660583  2880712108 2021-10-06  28.89      NaN         0.0       14.94
# 1660584  2880712108 2021-10-07  51.10      NaN         0.0       27.27
# 1660585  2880712108 2021-10-08  17.96      NaN         0.0        7.19
# 1660586  2880712108 2021-10-09  76.19      NaN         0.0       24.67
#
#          kwh_pap_r3  kwh_pap_r4
# 0               0.0       18.31
# 1               0.0       21.44
# 2               0.0       22.70
# 3               0.0       25.45
# 4               0.0       22.56
# ...             ...         ...
# 1660582         0.0       22.71
# 1660583         0.0       13.95
# 1660584         0.0       23.84
# 1660585         0.0       10.76
# 1660586         0.0       51.53
#
# [1660587 rows x 8 columns]

# %%
for cons_id in tqdm(cons_info_test.index):
    df = elec_day_test[elec_day_test["id"] == cons_id]
    if df.shape[0] == 0:
        continue
    df = df.drop(columns=["id"]).sort_values("rq").set_index("rq")
    df = df.fillna(method="ffill").fillna(method="bfill").fillna(0)
    cons_info_test.loc[cons_id, "kwh_mean"] = df["kwh"].mean()
    cons_info_test.loc[cons_id, "kwh_median"] = df["kwh"].median()
    cons_info_test.loc[cons_id, "kwh_std"] = df["kwh"].std()
    cons_info_test.loc[(cons_info_test.index == cons_id) & (cons_info_test["kwh_mean"] > 0), "kwh_std/mean"] = cons_info_test["kwh_std"] / cons_info_test["kwh_mean"]
    cons_info_test.loc[cons_id, "kwh_entropy"] = entropy(df["kwh"])
    cons_info_test.loc[cons_id, "kwh_pap_r12_distance"] = distance.euclidean(df["kwh_pap_r1"], df["kwh_pap_r2"])
    cons_info_test.loc[cons_id, "kwh_pap_r13_distance"] = distance.euclidean(df["kwh_pap_r1"], df["kwh_pap_r3"])
    cons_info_test.loc[cons_id, "kwh_pap_r14_distance"] = distance.euclidean(df["kwh_pap_r1"], df["kwh_pap_r4"])
    cons_info_test.loc[cons_id, "kwh_pap_r23_distance"] = distance.euclidean(df["kwh_pap_r2"], df["kwh_pap_r3"])
    cons_info_test.loc[cons_id, "kwh_pap_r24_distance"] = distance.euclidean(df["kwh_pap_r2"], df["kwh_pap_r4"])
    cons_info_test.loc[cons_id, "kwh_pap_r34_distance"] = distance.euclidean(df["kwh_pap_r3"], df["kwh_pap_r4"])

    cons_info_test.loc[cons_id, "kwh_pap_r12_cosine"] = cosine(df["kwh_pap_r1"], df["kwh_pap_r2"])
    cons_info_test.loc[cons_id, "kwh_pap_r13_cosine"] = cosine(df["kwh_pap_r1"], df["kwh_pap_r3"])
    cons_info_test.loc[cons_id, "kwh_pap_r14_cosine"] = cosine(df["kwh_pap_r1"], df["kwh_pap_r4"])
    cons_info_test.loc[cons_id, "kwh_pap_r23_cosine"] = cosine(df["kwh_pap_r2"], df["kwh_pap_r3"])
    cons_info_test.loc[cons_id, "kwh_pap_r24_cosine"] = cosine(df["kwh_pap_r2"], df["kwh_pap_r4"])
    cons_info_test.loc[cons_id, "kwh_pap_r34_cosine"] = cosine(df["kwh_pap_r3"], df["kwh_pap_r4"])
    
    cons_info_test.loc[cons_id, "kwh_pap_r1_cosine"] = cosine(df["kwh_pap_r1"], df["kwh"])
    cons_info_test.loc[cons_id, "kwh_pap_r2_cosine"] = cosine(df["kwh_pap_r2"], df["kwh"])
    cons_info_test.loc[cons_id, "kwh_pap_r3_cosine"] = cosine(df["kwh_pap_r3"], df["kwh"])
    cons_info_test.loc[cons_id, "kwh_pap_r4_cosine"] = cosine(df["kwh_pap_r4"], df["kwh"])
    
cons_info_test
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 15379/15379 [02:34<00:00, 99.42it/s]
#             CONTRACT_CAP  RUN_CAP  SHIFT_NO  CHK_CYCLE  live_days  check_days  \
# ID
# 179406029            2.0      2.0       1.0         24       8431        8431
# 179406030           12.0     12.0       0.0         24       8431        8431
# 179406094            2.0      2.0       1.0         24       8310        8310
# 179406097            4.0      4.0       1.0         36       8341        8341
# 179406099            2.0      2.0       1.0         24       8431        8431
# ...                  ...      ...       ...        ...        ...         ...
# 2849971818          12.0     12.0       0.0        120        783         783
# 2850017469         120.0    120.0       0.0        120        773         773
# 2850017472         720.0    720.0       0.0        120        773         773
# 2851323065          12.0     12.0       0.0        120        780         780
# 2852368013          52.5     52.5       0.0        120        741         741
#
#             ELEC_TYPE_NAME_乡村居民生活用电  ELEC_TYPE_NAME_商业用电  \
# ID
# 179406029                         0                    0
# 179406030                         0                    0
# 179406094                         0                    0
# 179406097                         0                    0
# 179406099                         0                    0
# ...                             ...                  ...
# 2849971818                        1                    0
# 2850017469                        1                    0
# 2850017472                        1                    0
# 2851323065                        0                    0
# 2852368013                        0                    0
#
#             ELEC_TYPE_NAME_城镇居民生活用电  ELEC_TYPE_NAME_学校教学和学生生活用电  ...  \
# ID                                                               ...
# 179406029                         1                           0  ...
# 179406030                         1                           0  ...
# 179406094                         1                           0  ...
# 179406097                         1                           0  ...
# 179406099                         1                           0  ...
# ...                             ...                         ...  ...
# 2849971818                        0                           0  ...
# 2850017469                        0                           0  ...
# 2850017472                        0                           0  ...
# 2851323065                        1                           0  ...
# 2852368013                        1                           0  ...
#
#             kwh_pap_r12_cosine  kwh_pap_r13_cosine  kwh_pap_r14_cosine  \
# ID
# 179406029                  1.0                 0.0                 1.0
# 179406030                  0.0                 1.0                 0.0
# 179406094                  1.0                 0.0                 1.0
# 179406097                  1.0                 0.0                 1.0
# 179406099                  1.0                 0.0                 1.0
# ...                        ...                 ...                 ...
# 2849971818                 1.0                 0.0                 1.0
# 2850017469                 0.0                 0.0                 0.0
# 2850017472                 1.0                 1.0                 1.0
# 2851323065                 1.0                 0.0                 1.0
# 2852368013                 1.0                 1.0                 1.0
#
#             kwh_pap_r23_cosine  kwh_pap_r24_cosine  kwh_pap_r34_cosine  \
# ID
# 179406029             1.000000            0.103449            1.000000
# 179406030             1.000000            0.000000            1.000000
# 179406094             1.000000            0.097529            1.000000
# 179406097             1.000000            0.113770            1.000000
# 179406099             1.000000            0.082221            1.000000
# ...                        ...                 ...                 ...
# 2849971818            1.000000            0.672559            1.000000
# 2850017469            0.000000            0.000000            0.000000
# 2850017472            0.002637            0.008105            0.009052
# 2851323065            1.000000            0.184983            1.000000
# 2852368013            0.000445            0.009737            0.008936
#
#             kwh_pap_r1_cosine  kwh_pap_r2_cosine  kwh_pap_r3_cosine  \
# ID
# 179406029                 1.0           0.015134           1.000000
# 179406030                 1.0           1.000000           0.000000
# 179406094                 1.0           0.000859           1.000000
# 179406097                 1.0           0.016689           1.000000
# 179406099                 1.0           0.009680           1.000000
# ...                       ...                ...                ...
# 2849971818                1.0           0.402164           1.000000
# 2850017469                0.0           0.000000           0.000000
# 2850017472                1.0           0.000969           0.001243
# 2851323065                1.0           0.004505           1.000000
# 2852368013                1.0           0.000884           0.000661
#
#             kwh_pap_r4_cosine
# ID
# 179406029            0.040248
# 179406030            1.000000
# 179406094            0.080452
# 179406097            0.044281
# 179406099            0.035987
# ...                       ...
# 2849971818           0.064085
# 2850017469           0.000000
# 2850017472           0.004624
# 2851323065           0.133719
# 2852368013           0.004958
#
# [15379 rows x 55 columns]

# %%
cons_info_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15379 entries, 179406029 to 2852368013
# Data columns (total 55 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CONTRACT_CAP                15379 non-null  float64
#  1   RUN_CAP                     15379 non-null  float64
#  2   SHIFT_NO                    15379 non-null  float64
#  3   CHK_CYCLE                   15379 non-null  int64
#  4   live_days                   15379 non-null  int64
#  5   check_days                  15379 non-null  int64
#  6   ELEC_TYPE_NAME_乡村居民生活用电     15379 non-null  uint8
#  7   ELEC_TYPE_NAME_商业用电         15379 non-null  uint8
#  8   ELEC_TYPE_NAME_城镇居民生活用电     15379 non-null  uint8
#  9   ELEC_TYPE_NAME_学校教学和学生生活用电  15379 non-null  uint8
#  10  ELEC_TYPE_NAME_居民生活用电       15379 non-null  uint8
#  11  ELEC_TYPE_NAME_普通工业         15379 non-null  uint8
#  12  ELEC_TYPE_NAME_非居民照明        15379 non-null  uint8
#  13  ELEC_TYPE_NAME_非工业          15379 non-null  uint8
#  14  VOLT_NAME_交流10kV            15379 non-null  uint8
#  15  VOLT_NAME_交流220V            15379 non-null  uint8
#  16  VOLT_NAME_交流380V            15379 non-null  uint8
#  17  PRC_NAME_居民合表电价(1-10千伏）     15379 non-null  uint8
#  18  PRC_NAME_居民合表电价(不满1千伏）      15379 non-null  uint8
#  19  TMP_NAME_非临时用电              15379 non-null  uint8
#  20  pq_z_mean                   15379 non-null  float64
#  21  pq_z_median                 15379 non-null  float64
#  22  pq_z_std                    15379 non-null  float64
#  23  pq_z_std/mean               15379 non-null  float64
#  24  pq_z_entropy                15379 non-null  float64
#  25  pq_fg_distance              15379 non-null  float64
#  26  pq_gp_diatance              15379 non-null  float64
#  27  pq_fp_distance              15379 non-null  float64
#  28  pq_fg_cosine                15379 non-null  float64
#  29  pq_gp_cosine                15379 non-null  float64
#  30  pq_fp_cosine                15379 non-null  float64
#  31  pq_fz_cosine                15379 non-null  float64
#  32  pq_gz_cosine                15379 non-null  float64
#  33  pq_pz_cosine                15379 non-null  float64
#  34  kwh_mean                    15379 non-null  float64
#  35  kwh_median                  15379 non-null  float64
#  36  kwh_std                     15379 non-null  float64
#  37  kwh_std/mean                15379 non-null  float64
#  38  kwh_entropy                 15379 non-null  float64
#  39  kwh_pap_r12_distance        15379 non-null  float64
#  40  kwh_pap_r13_distance        15379 non-null  float64
#  41  kwh_pap_r14_distance        15379 non-null  float64
#  42  kwh_pap_r23_distance        15379 non-null  float64
#  43  kwh_pap_r24_distance        15379 non-null  float64
#  44  kwh_pap_r34_distance        15379 non-null  float64
#  45  kwh_pap_r12_cosine          15379 non-null  float64
#  46  kwh_pap_r13_cosine          15379 non-null  float64
#  47  kwh_pap_r14_cosine          15379 non-null  float64
#  48  kwh_pap_r23_cosine          15379 non-null  float64
#  49  kwh_pap_r24_cosine          15379 non-null  float64
#  50  kwh_pap_r34_cosine          15379 non-null  float64
#  51  kwh_pap_r1_cosine           15379 non-null  float64
#  52  kwh_pap_r2_cosine           15379 non-null  float64
#  53  kwh_pap_r3_cosine           15379 non-null  float64
#  54  kwh_pap_r4_cosine           15379 non-null  float64
# dtypes: float64(38), int64(3), uint8(14)
# memory usage: 5.8 MB

# %% [markdown]
# <h2>重新排列测试集</h2>

# %%
cons_info_test = cons_info_test.reindex(columns=cons_info.columns).drop(columns=["IS_FLAG"])
cons_info_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15379 entries, 179406029 to 2852368013
# Data columns (total 55 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CONTRACT_CAP                15379 non-null  float64
#  1   RUN_CAP                     15379 non-null  float64
#  2   SHIFT_NO                    15379 non-null  float64
#  3   CHK_CYCLE                   15379 non-null  int64
#  4   live_days                   15379 non-null  int64
#  5   check_days                  15379 non-null  int64
#  6   ELEC_TYPE_NAME_乡村居民生活用电     15379 non-null  uint8
#  7   ELEC_TYPE_NAME_商业用电         15379 non-null  uint8
#  8   ELEC_TYPE_NAME_城镇居民生活用电     15379 non-null  uint8
#  9   ELEC_TYPE_NAME_学校教学和学生生活用电  15379 non-null  uint8
#  10  ELEC_TYPE_NAME_居民生活用电       15379 non-null  uint8
#  11  ELEC_TYPE_NAME_普通工业         15379 non-null  uint8
#  12  ELEC_TYPE_NAME_非居民照明        15379 non-null  uint8
#  13  ELEC_TYPE_NAME_非工业          15379 non-null  uint8
#  14  VOLT_NAME_交流10kV            15379 non-null  uint8
#  15  VOLT_NAME_交流220V            15379 non-null  uint8
#  16  VOLT_NAME_交流380V            15379 non-null  uint8
#  17  PRC_NAME_居民合表电价(1-10千伏）     15379 non-null  uint8
#  18  PRC_NAME_居民合表电价(不满1千伏）      15379 non-null  uint8
#  19  TMP_NAME_非临时用电              15379 non-null  uint8
#  20  pq_z_mean                   15379 non-null  float64
#  21  pq_z_median                 15379 non-null  float64
#  22  pq_z_std                    15379 non-null  float64
#  23  pq_z_std/mean               15379 non-null  float64
#  24  pq_z_entropy                15379 non-null  float64
#  25  pq_fg_distance              15379 non-null  float64
#  26  pq_gp_diatance              15379 non-null  float64
#  27  pq_fp_distance              15379 non-null  float64
#  28  pq_fg_cosine                15379 non-null  float64
#  29  pq_gp_cosine                15379 non-null  float64
#  30  pq_fp_cosine                15379 non-null  float64
#  31  pq_fz_cosine                15379 non-null  float64
#  32  pq_gz_cosine                15379 non-null  float64
#  33  pq_pz_cosine                15379 non-null  float64
#  34  kwh_mean                    15379 non-null  float64
#  35  kwh_median                  15379 non-null  float64
#  36  kwh_std                     15379 non-null  float64
#  37  kwh_std/mean                15379 non-null  float64
#  38  kwh_entropy                 15379 non-null  float64
#  39  kwh_pap_r12_distance        15379 non-null  float64
#  40  kwh_pap_r13_distance        15379 non-null  float64
#  41  kwh_pap_r14_distance        15379 non-null  float64
#  42  kwh_pap_r23_distance        15379 non-null  float64
#  43  kwh_pap_r24_distance        15379 non-null  float64
#  44  kwh_pap_r34_distance        15379 non-null  float64
#  45  kwh_pap_r12_cosine          15379 non-null  float64
#  46  kwh_pap_r13_cosine          15379 non-null  float64
#  47  kwh_pap_r14_cosine          15379 non-null  float64
#  48  kwh_pap_r23_cosine          15379 non-null  float64
#  49  kwh_pap_r24_cosine          15379 non-null  float64
#  50  kwh_pap_r34_cosine          15379 non-null  float64
#  51  kwh_pap_r1_cosine           15379 non-null  float64
#  52  kwh_pap_r2_cosine           15379 non-null  float64
#  53  kwh_pap_r3_cosine           15379 non-null  float64
#  54  kwh_pap_r4_cosine           15379 non-null  float64
# dtypes: float64(38), int64(3), uint8(14)
# memory usage: 5.8 MB

# %%
x_test = ss.transform(cons_info_test.values)
x_test.shape
# Out:
# (15379, 55)

# %%
x_test
# Out:
# array([[-0.34570468, -0.35332375,  1.05812375, ..., -0.19047615,
#          0.53828596, -0.20511538],
#        [-0.18021871, -0.18256316, -0.86811471, ...,  5.88868611,
#         -1.93452962,  5.04390581],
#        [-0.34570468, -0.35332375,  1.05812375, ..., -0.27858649,
#          0.53828596,  0.0147641 ],
#        ...,
#        [11.53618784, 11.90728646, -0.86811471, ..., -0.27790806,
#         -1.93145671, -0.39995146],
#        [-0.18021871, -0.18256316, -0.86811471, ..., -0.25608517,
#          0.53828596,  0.30609063],
#        [ 0.48999946,  0.50901722, -0.86811471, ..., -0.27843504,
#         -1.93289553, -0.39812478]])

# %% [markdown]
# <h2>预测数据</h2>

# %%
y_test = model.predict(x_test)
cons_info_test["label"] = y_test
cons_info_test
# Out:
#             CONTRACT_CAP  RUN_CAP  SHIFT_NO  CHK_CYCLE  live_days  check_days  \
# ID
# 179406029            2.0      2.0       1.0         24       8431        8431
# 179406030           12.0     12.0       0.0         24       8431        8431
# 179406094            2.0      2.0       1.0         24       8310        8310
# 179406097            4.0      4.0       1.0         36       8341        8341
# 179406099            2.0      2.0       1.0         24       8431        8431
# ...                  ...      ...       ...        ...        ...         ...
# 2849971818          12.0     12.0       0.0        120        783         783
# 2850017469         120.0    120.0       0.0        120        773         773
# 2850017472         720.0    720.0       0.0        120        773         773
# 2851323065          12.0     12.0       0.0        120        780         780
# 2852368013          52.5     52.5       0.0        120        741         741
#
#             ELEC_TYPE_NAME_乡村居民生活用电  ELEC_TYPE_NAME_商业用电  \
# ID
# 179406029                         0                    0
# 179406030                         0                    0
# 179406094                         0                    0
# 179406097                         0                    0
# 179406099                         0                    0
# ...                             ...                  ...
# 2849971818                        1                    0
# 2850017469                        1                    0
# 2850017472                        1                    0
# 2851323065                        0                    0
# 2852368013                        0                    0
#
#             ELEC_TYPE_NAME_城镇居民生活用电  ELEC_TYPE_NAME_学校教学和学生生活用电  ...  \
# ID                                                               ...
# 179406029                         1                           0  ...
# 179406030                         1                           0  ...
# 179406094                         1                           0  ...
# 179406097                         1                           0  ...
# 179406099                         1                           0  ...
# ...                             ...                         ...  ...
# 2849971818                        0                           0  ...
# 2850017469                        0                           0  ...
# 2850017472                        0                           0  ...
# 2851323065                        1                           0  ...
# 2852368013                        1                           0  ...
#
#             kwh_pap_r13_cosine  kwh_pap_r14_cosine  kwh_pap_r23_cosine  \
# ID
# 179406029                  0.0                 1.0            1.000000
# 179406030                  1.0                 0.0            1.000000
# 179406094                  0.0                 1.0            1.000000
# 179406097                  0.0                 1.0            1.000000
# 179406099                  0.0                 1.0            1.000000
# ...                        ...                 ...                 ...
# 2849971818                 0.0                 1.0            1.000000
# 2850017469                 0.0                 0.0            0.000000
# 2850017472                 1.0                 1.0            0.002637
# 2851323065                 0.0                 1.0            1.000000
# 2852368013                 1.0                 1.0            0.000445
#
#             kwh_pap_r24_cosine  kwh_pap_r34_cosine  kwh_pap_r1_cosine  \
# ID
# 179406029             0.103449            1.000000                1.0
# 179406030             0.000000            1.000000                1.0
# 179406094             0.097529            1.000000                1.0
# 179406097             0.113770            1.000000                1.0
# 179406099             0.082221            1.000000                1.0
# ...                        ...                 ...                ...
# 2849971818            0.672559            1.000000                1.0
# 2850017469            0.000000            0.000000                0.0
# 2850017472            0.008105            0.009052                1.0
# 2851323065            0.184983            1.000000                1.0
# 2852368013            0.009737            0.008936                1.0
#
#             kwh_pap_r2_cosine  kwh_pap_r3_cosine  kwh_pap_r4_cosine  label
# ID
# 179406029            0.015134           1.000000           0.040248      0
# 179406030            1.000000           0.000000           1.000000      0
# 179406094            0.000859           1.000000           0.080452      0
# 179406097            0.016689           1.000000           0.044281      0
# 179406099            0.009680           1.000000           0.035987      0
# ...                       ...                ...                ...    ...
# 2849971818           0.402164           1.000000           0.064085      0
# 2850017469           0.000000           0.000000           0.000000      0
# 2850017472           0.000969           0.001243           0.004624      0
# 2851323065           0.004505           1.000000           0.133719      0
# 2852368013           0.000884           0.000661           0.004958      0
#
# [15379 rows x 56 columns]

# %%
cons_info_test.index.name = "id"
cons_info_test[["label"]].to_csv("../data/result20220209-2.csv", index=True)
