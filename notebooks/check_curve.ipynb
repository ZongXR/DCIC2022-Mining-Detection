# %%
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
cons_no = 874996400

# %%
cons_info = pd.read_csv("../data/测试组_比特币挖矿_档案明细（20211220）.csv", index_col=0, quotechar='"', encoding="gbk")

# %%
cons_info_one = cons_info[cons_info.index == cons_no]
cons_info_one
# Out:
#           ELEC_TYPE_NAME VOLT_NAME      PRC_NAME  CONTRACT_CAP  RUN_CAP  \
# ID
# 874996400       乡村居民生活用电    交流380V  居民生活<1kV(合表)         550.0    550.0
#
#            SHIFT_NO  BUILD_DATE CANCEL_DATE  CHK_CYCLE LAST_CHK_DATE TMP_NAME  \
# ID
# 874996400       NaN  2009/10/16         NaN         24     2019/1/31    非临时用电
#
#            TMP_DATE
# ID
# 874996400       NaN

# %%
elec_month = pd.read_csv("../data/测试组_比特币挖矿_月用电明细（20211217）.csv")
elec_month
# Out:
#                 id      ym  pq_f  pq_g  pq_p  pq_z
# 0        179438260  202001   244   111     1   356
# 1        179438260  202002   217   108    -1   324
# 2        179438260  202003   280    90     0   370
# 3        179438260  202004   338   118     1   457
# 4        179438260  202005   297   120    -1   416
# ...            ...     ...   ...   ...   ...   ...
# 338333  2880712108  202106   474   675     0  1149
# 338334  2880712108  202107   342   881     0  1223
# 338335  2880712108  202108   293   772     0  1065
# 338336  2880712108  202109   418   570    -1   987
# 338337  2880712108  202110   549   535     1  1085
#
# [338338 rows x 6 columns]

# %%
elec_month["ym"] = elec_month["ym"].astype(str)
elec_month
# Out:
#                 id      ym  pq_f  pq_g  pq_p  pq_z
# 0        179438260  202001   244   111     1   356
# 1        179438260  202002   217   108    -1   324
# 2        179438260  202003   280    90     0   370
# 3        179438260  202004   338   118     1   457
# 4        179438260  202005   297   120    -1   416
# ...            ...     ...   ...   ...   ...   ...
# 338333  2880712108  202106   474   675     0  1149
# 338334  2880712108  202107   342   881     0  1223
# 338335  2880712108  202108   293   772     0  1065
# 338336  2880712108  202109   418   570    -1   987
# 338337  2880712108  202110   549   535     1  1085
#
# [338338 rows x 6 columns]

# %%
elec_month_one = elec_month[elec_month["id"] == cons_no]
elec_month_one
# Out:
#                id      ym  pq_f  pq_g  pq_p   pq_z
# 193600  874996400  202001  3285  2962  3369   9616
# 193601  874996400  202002  2997  2715  3019   8731
# 193602  874996400  202003  2594  2418  2634   7646
# 193603  874996400  202004  2874  2611  2929   8414
# 193604  874996400  202005  2859  2555  2936   8350
# 193605  874996400  202006  3133  2778  3199   9110
# 193606  874996400  202007  3096  2736  3184   9016
# 193607  874996400  202008  3229  2870  3315   9414
# 193608  874996400  202009  3235  2811  3281   9327
# 193609  874996400  202010  6810  5952  7004  19766
# 193610  874996400  202011  2901  2486  3027   8414
# 193611  874996400  202012  2912  2539  3034   8485
# 193612  874996400  202101  2766  2402  2850   8018
# 193613  874996400  202102  2360  2118  2367   6845
# 193614  874996400  202103  2312  1962  2404   6678
# 193615  874996400  202104  2222  1885  2323   6430
# 193616  874996400  202105  2357  1994  2428   6779
# 193617  874996400  202106  2310  1939  2375   6624
# 193618  874996400  202107  2446  2034  2453   6933
# 193619  874996400  202108  2378  1981  2387   6746
# 193620  874996400  202109  2261  1917  2347   6525
# 193621  874996400  202110  2358  1962  2422   6742

# %%
elec_month_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 193600 to 193621
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      22 non-null     int64
#  1   ym      22 non-null     object
#  2   pq_f    22 non-null     int64
#  3   pq_g    22 non-null     int64
#  4   pq_p    22 non-null     int64
#  5   pq_z    22 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.2+ KB

# %%
plt.figure(1)
plt.plot(elec_month_one["ym"], elec_month_one["pq_f"], color="r", label="pq_f")
plt.plot(elec_month_one["ym"], elec_month_one["pq_g"], color="g", label="pq_g")
plt.plot(elec_month_one["ym"], elec_month_one["pq_p"], color="b", label="pq_p")
plt.xlabel("ym")
plt.ylabel("elec_month")
plt.title("month_curve")
plt.xticks(rotation=60)
plt.legend()
plt.tight_layout()
plt.show()

# %%
elec_day = pd.read_csv("../data/测试组_比特币挖矿_日用电明细（20211217）.csv")
elec_day["rq"] = pd.to_datetime(elec_day["rq"])
elec_day_one = elec_day[elec_day["id"] == cons_no]
elec_day_one
# Out:
#                id         rq    kwh  kwh_rap  kwh_pap_r1  kwh_pap_r2  \
# 950258  874996400 2020-01-22  276.8      NaN         0.0        94.4
# 950259  874996400 2020-01-23  275.2      NaN         0.0        96.0
# 950260  874996400 2020-01-24  273.6      NaN         0.0        94.4
# 950261  874996400 2020-01-25  260.8      NaN         0.0        88.0
# 950262  874996400 2020-01-26  260.8      NaN         0.0        86.4
# ...           ...        ...    ...      ...         ...         ...
# 950361  874996400 2021-10-05  217.6      NaN         0.0        78.4
# 950362  874996400 2021-10-06  217.6      NaN         0.0        76.8
# 950363  874996400 2021-10-07  219.2      NaN         0.0        78.4
# 950364  874996400 2021-10-08  220.8      NaN         0.0        75.2
# 950365  874996400 2021-10-09  225.6      NaN         0.0        76.8
#
#         kwh_pap_r3  kwh_pap_r4
# 950258        96.0        86.4
# 950259        94.4        84.8
# 950260        92.8        86.4
# 950261        88.0        84.8
# 950262        86.4        88.0
# ...            ...         ...
# 950361        76.8        62.4
# 950362        76.8        64.0
# 950363        76.8        64.0
# 950364        81.6        64.0
# 950365        83.2        65.6
#
# [108 rows x 8 columns]

# %%
plt.figure(2)
plt.plot(list(range(elec_day_one["kwh_pap_r2"].shape[0])), elec_day_one["kwh_pap_r2"], color="r", label="kwh_pap_r2")
plt.plot(list(range(elec_day_one["kwh_pap_r3"].shape[0])), elec_day_one["kwh_pap_r3"], color="g", label="kwh_pap_r3")
plt.plot(list(range(elec_day_one["kwh_pap_r3"].shape[0])), elec_day_one["kwh_pap_r4"], color="b", label="kwh_pap_r4")
plt.xlabel("rq")
plt.ylabel("elec_day")
plt.title("day_curve")
plt.xticks(rotation=60)
plt.legend()
plt.tight_layout()
plt.show()

# %%
submit = pd.read_csv("../data/result20220304-3.csv")
submit = submit[submit["label"] == 1]
submit
# Out:
#                id  label
# 742     179418058      1
# 1815    179458306      1
# 5115    855996491      1
# 6470   1606708811      1
# 6825   2071313507      1
# 7237   2347718608      1
# 7517   2238809293      1
# 7929   2533183958      1
# 8184   2496032641      1
# 8264   2427050072      1
# 8554   2717225077      1
# 8619   2741872006      1
# 8629   2745781539      1
# 8641   2755128229      1
# 8655   2759232590      1
# 8995    179569820      1
# 11594   179547052      1
# 13618  2172970175      1
# 13644  2186749200      1
# 13677  2194274407      1
# 13717  2212416005      1
# 13840  2251440776      1
# 13855  2256064355      1
# 13970  2319973783      1
# 14019  2347718610      1
# 14138  2445049876      1
# 14257  2479963778      1
# 14322  2523401557      1
# 14452  2540517219      1
# 14554  2576321385      1
# 14590  2602819207      1
# 14800  1916407803      1
# 15056  2759317616      1
# 15331  2825175309      1

# %%
for i in range(submit.shape[0]):
    plt.figure(3 + i)
    plt.subplots(1, 2, figsize=(10, 5))
    cons_month = elec_month[elec_month["id"] == submit.iloc[i, 0]]
    cons_day = elec_day[elec_day["id"] == submit.iloc[i, 0]]
    
    ax0 = plt.subplot(1, 2, 1)
    plt.plot(cons_month["ym"], cons_month["pq_f"], color="r", label="pq_f")
    plt.plot(cons_month["ym"], cons_month["pq_g"], color="g", label="pq_g")
    plt.plot(cons_month["ym"], cons_month["pq_p"], color="b", label="pq_p")
    ax0.set_title(submit.iloc[i, 0])
    ax0.set_xlabel("ym")
    ax0.set_ylabel("elec_month")
    ax0.set_xticklabels(cons_month["ym"], rotation=60)
    ax0.legend()
    
    ax1 = plt.subplot(1, 2, 2)
    plt.plot(list(range(cons_day["kwh_pap_r2"].shape[0])), cons_day["kwh_pap_r2"], color="r", label="kwh_pap_r2")
    plt.plot(list(range(cons_day["kwh_pap_r3"].shape[0])), cons_day["kwh_pap_r3"], color="g", label="kwh_pap_r3")
    plt.plot(list(range(cons_day["kwh_pap_r3"].shape[0])), cons_day["kwh_pap_r4"], color="b", label="kwh_pap_r4")
    ax1.set_title(submit.iloc[i, 0])
    ax1.set_xlabel("rq")
    ax1.set_ylabel("elec_day")
    ax1.set_xticklabels(list(range(cons_day["kwh_pap_r2"].shape[0])), rotation=60)
    ax1.legend()
    
    plt.tight_layout()
    plt.show()
